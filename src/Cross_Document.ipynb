# %% [markdown]
# ## <b>Relevant Paper Retrieval</b>
#
# We begin by doing a keyword search on the scopus API, for a given MOF. We return the abstracts of the most relevant papers. Since this query is very general, we want to return as many papers as possible at this stage.
#
# Following this, we will do a vector similarity search on all the abstracts, to return a list of the most relevant papers to our query. After that, using the results from cross-documentation, synthesis extraction is performed (the exact same way as ```ChemUnity_Synthesis.ipynb```) as an example.

# %%
import requests
import openai
import numpy as np
import pandas as pd
import faiss
import time  
import os
import glob
from langchain_openai import ChatOpenAI
from langchain.callbacks import get_openai_callback

from MOF_ChemUnity.utils.cross_doc_utils import CrossDocUtil
from MOF_ChemUnity.Agents.ExtractionAgent import ExtractionAgent
from MOF_ChemUnity.utils.DocProcessor import DocProcessor
from MOF_ChemUnity.Prompts.Synthesis_Prompts import SYNTHESIS_EXTRACTION
from MOF_ChemUnity.utils.DataModels import Synthesis

# %% [markdown]
# <b>Searching Scopus for articles related to the given MOF name and synthesis, retrieves metadata (Title, DOI), and fetches full abstracts.</b>
#
# For this, the SCOPUS_API_KEY is utilized to access DOIs available online to find the desired MOF (in this example, HKUST-1 has been used). From this, ```paper_df``` is used to map the:
# 1. Title of paper
# 2. Abstract of paper
# 3. DOI of paper

# %%
# Set API keys (replace with your own API keys)
SCOPUS_API_KEY = "YOUR_SCOPUS_API_KEY"
OPENAI_API_KEY = "YOUR_OPENAI_API_KEY"
openai.api_key = OPENAI_API_KEY

# %%
# Search Scopus
MOF_NAME = "HKUST-1"  # Change to the desired MOF
papers_df = CrossDocUtil(SCOPUS_API_KEY = SCOPUS_API_KEY).search_scopus(MOF_NAME, count=500)
papers_df = papers_df[papers_df["doi"] != "N/A"].reset_index(drop=True)
papers_df
# Out:
#                                                  title  \
# 0    Optimizing CO<inf>2</inf> hydrogenation to met...
# 1    In-situ growth of metal–organic framework on i...
# 2    Scalable upgrading metal–organic frameworks th...
# 3    Ion exchange- and enrichment-based technology ...
# 4    Ratiometric fluorescence assay for ciprofloxac...
# ..                                                 ...
# 490  Hybrid polymer/MOF membranes for Organic Solve...
# 491  On controlling the anodic electrochemical film...
# 492  Bi<inf>2</inf>O<inf>3</inf> nanoparticles enca...
# 493  Continuous-Flow Microwave Synthesis of Metal-O...
# 494  Reticular Synthesis of HKUST-like tbo-MOFs wit...
#
#                                               abstract  \
# 0    Designing an active Cu/ZnO interface is crucia...
# 1    The environmental risks posed by tetracycline ...
# 2    Some well-established metal–organic frameworks...
# 3    Mass spectrometry (MS) based proteomics provid...
# 4    Preparation of carbon dots (CDs) from biomass ...
# ..                                                 ...
# 490  One of the main challenges in the field of Org...
# 491  Anodic electrochemical synthesis presents itse...
# 492  We describe a novel procedure to fabricate a r...
# 493  Metal-organic frameworks are having a tremendo...
# 494  Successful implementation of reticular chemist...
#
#                                  doi
# 0       10.1016/j.apcatb.2025.125334
# 1       10.1016/j.seppur.2025.132707
# 2       10.1016/j.seppur.2025.132270
# 3       10.1016/j.chroma.2025.465914
# 4      10.1016/j.talanta.2024.127477
# ..                               ...
# 490     10.1016/j.memsci.2016.01.024
# 491  10.1016/j.micromeso.2015.11.060
# 492               10.1039/c6nr00532b
# 493           10.1002/chem.201505139
# 494             10.1021/jacs.5b11079
#
# [495 rows x 3 columns]

# %% [markdown]
# Now, we will save our ```papers_df``` to a csv, and append MOF_Name to all the rows. This implementation is only for one MOF at a time, but we could easily run this for all MOF names in our database. Then append the abstracts and DOIs to our master dataframe.

# %%
# Compute embeddings for all abstracts
abstracts = papers_df["abstract"].tolist()
embeddings = np.array([CrossDocUtil(SCOPUS_API_KEY = SCOPUS_API_KEY).get_embedding(abstract) for abstract in abstracts])

# Initialize FAISS vector database
dimension = embeddings.shape[1]
index = faiss.IndexFlatL2(dimension)
index.add(embeddings)

# %%
# Example query
query = (
    f"Comprehensive review of synthesis methods for {MOF_NAME}, including solvothermal, "
    "mechanochemical, and microwave-assisted routes, along with comparative analyses of "
    "reaction conditions and yield optimization. Also includes experimental studies detailing "
    f"synthesis procedures and characterization of {MOF_NAME}."
)
results = CrossDocUtil(SCOPUS_API_KEY = SCOPUS_API_KEY).vector_search(query, index, abstracts, top_k=495)

# Get the columns of papers_df
results_columns = papers_df.columns.tolist()

# Prepare results for DataFrame with the same structure as papers_df
results_data = []

for abstract, idx in results:
    row_data = papers_df.loc[idx].to_dict()  # Get full row from papers_df
    row_data["MOF Name"] = MOF_NAME  # Add MOF Name column
    results_data.append(row_data)

# Create DataFrame with the same columns as papers_df + "MOF Name"
relevant_papers_df = pd.DataFrame(results_data, columns=results_columns + ["MOF Name"])
relevant_papers_df
# Out:
#                                                  title  \
# 0    Synthesis and Characterization of Ultrapure HK...
# 1    Mesoporous HKUST-1 synthesized using solvother...
# 2    Statistically optimum HKUST-1 synthesized by r...
# 3    Direct synthesis of Al-HKUST-1 and its applica...
# 4    HKUST-1-supported cerium catalysts for CO oxid...
# ..                                                 ...
# 490  An antibiotic-free platform for eliminating pe...
# 491  Precise assembly of a zeolite imidazolate fram...
# 492  Built-in skeleton Cu/NC-NFs as a sulfur carrie...
# 493  Continuous Synthesis of Metal-Organic Framewor...
# 494  Adsorption of silver nanoparticles from aqueou...
#
#                                               abstract  \
# 0    Herein, an ultrapure HKUST-1 MOFs synthesized ...
# 1    Metal-organic frameworks type HKUST-1 were syn...
# 2    Due to its excellency and versatility, many sy...
# 3    Direct synthesis of Al-HKUST-1 was successfull...
# 4    The synthesis method of metal–organic framewor...
# ..                                                 ...
# 490  Helicobacter pylori (H. pylori) infection rema...
# 491  Polypropylene (PP) has been widely used in the...
# 492  Carbon nanofibers are commendable sulfur carri...
# 493                              No abstract available
# 494  Silver nanoparticles (AgNP) are emerging pollu...
#
#                                    doi MOF Name
# 0               10.1002/slct.201904637  HKUST-1
# 1            10.31788/RJC.2019.1231968  HKUST-1
# 2            10.3390/molecules26216430  HKUST-1
# 3         10.1016/j.nanoso.2021.100773  HKUST-1
# 4                10.3390/catal10010108  HKUST-1
# ..                                 ...      ...
# 490         10.1016/j.apsb.2024.03.014  HKUST-1
# 491       10.1016/j.memsci.2020.118412  HKUST-1
# 492                 10.1039/d5cc00529a  HKUST-1
# 493                  10.11203/jar.34.5  HKUST-1
# 494  10.1016/j.chemosphere.2016.02.005  HKUST-1
#
# [495 rows x 4 columns]

# %% [markdown]
# <b> Downloading Relevant Papers</b>
#
# Now that we have the relevant papers, the PDFs can be downloaded by utilizing ``CrossDocUtil(SCOPUS_API_KEY).download_full_texts(df)``. Feel free to refer to the utils function for more information.

# %%
save_path = "Cross_Document_Linking/XML"
os.makedirs(save_path, exist_ok=True)  # Create the folder if it doesn't exist

CrossDocUtil(SCOPUS_API_KEY=SCOPUS_API_KEY).download_full_texts(relevant_papers_df, save_path)
# Out:
# Requesting: https://api.elsevier.com/content/article/doi/10.1002%2Fslct.201904637?view=FULL
# DOI not found: 10.1002/slct.201904637 (Status: 404)
# Requesting: https://api.elsevier.com/content/article/doi/10.31788%2FRJC.2019.1231968?view=FULL
# DOI not found: 10.31788/RJC.2019.1231968 (Status: 404)
# Requesting: https://api.elsevier.com/content/article/doi/10.3390%2Fmolecules26216430?view=FULL
# DOI not found: 10.3390/molecules26216430 (Status: 404)
# Requesting: https://api.elsevier.com/content/article/doi/10.1016%2Fj.nanoso.2021.100773?view=FULL
# Downloaded: Cross_Document_Linking/XML/10.1016_j.nanoso.2021.100773.xml
# Requesting: https://api.elsevier.com/content/article/doi/10.3390%2Fcatal10010108?view=FULL
# DOI not found: 10.3390/catal10010108 (Status: 404)
# Requesting: https://api.elsevier.com/content/article/doi/10.1016%2Fj.pnsc.2018.08.002?view=FULL
# Downloaded: Cross_Document_Linking/XML/10.1016_j.pnsc.2018.08.002.xml
# Requesting: https://api.elsevier.com/content/article/doi/10.1039%2Fd3nj06001b?view=FULL
# DOI not found: 10.1039/d3nj06001b (Status: 404)
# Requesting: https://api.elsevier.com/content/article/doi/10.1021%2Facs.inorgchem.7b00707?view=FULL
# DOI not found: 10.1021/acs.inorgchem.7b00707 (Status: 404)
# Requesting: https://api.elsevier.com/content/article/doi/10.1021%2Facsomega.4c01852?view=FULL
# DOI not found: 10.1021/acsomega.4c01852 (Status: 404)
# Requesting: https://api.elsevier.com/content/article/doi/10.1016%2Fj.synthmet.2016.07.003?view=FULL
# Downloaded: Cross_Document_Linking/XML/10.1016_j.synthmet.2016.07.003.xml
# Requesting: https://api.elsevier.com/content/article/doi/10.1016%2Fj.cej.2017.05.169?view=FULL
# Downloaded: Cross_Document_Linking/XML/10.1016_j.cej.2017.05.169.xml
# Requesting: https://api.elsevier.com/content/article/doi/10.1021%2Facs.inorgchem.2c02490?view=FULL
# DOI not found: 10.1021/acs.inorgchem.2c02490 (Status: 404)
# Requesting: https://api.elsevier.com/content/article/doi/10.1016%2Fj.micromeso.2018.05.027?view=FULL
# Downloaded: Cross_Document_Linking/XML/10.1016_j.micromeso.2018.05.027.xml
# Requesting: https://api.elsevier.com/content/article/doi/10.1039%2Fd1ra00942g?view=FULL
# DOI not found: 10.1039/d1ra00942g (Status: 404)
# Requesting: https://api.elsevier.com/content/article/doi/10.1016%2FS1872-2067%2817%2962874-2?view=FULL
# Downloaded: Cross_Document_Linking/XML/10.1016_S1872-2067(17)62874-2.xml
# Requesting: https://api.elsevier.com/content/article/doi/10.58915%2Fijneam.v17iDecember.1638?view=FULL
# DOI not found: 10.58915/ijneam.v17iDecember.1638 (Status: 404)
# Requesting: https://api.elsevier.com/content/article/doi/10.1016%2Fj.poly.2021.115517?view=FULL
# Downloaded: Cross_Document_Linking/XML/10.1016_j.poly.2021.115517.xml
# Requesting: https://api.elsevier.com/content/article/doi/10.3390%2Fcryst12020279?view=FULL
# DOI not found: 10.3390/cryst12020279 (Status: 404)
# Requesting: https://api.elsevier.com/content/article/doi/10.1093%2Fchemle%2Fupae109?view=FULL
# DOI not found: 10.1093/chemle/upae109 (Status: 404)
# Requesting: https://api.elsevier.com/content/article/doi/10.3390%2Fmolecules25112648?view=FULL
# DOI not found: 10.3390/molecules25112648 (Status: 404)
# Requesting: https://api.elsevier.com/content/article/doi/10.1039%2Fc9ce01676g?view=FULL
# DOI not found: 10.1039/c9ce01676g (Status: 404)
# Requesting: https://api.elsevier.com/content/article/doi/10.1038%2Fs41467-023-40737-5?view=FULL
# DOI not found: 10.1038/s41467-023-40737-5 (Status: 404)
# Requesting: https://api.elsevier.com/content/article/doi/10.1016%2Fj.ijbiomac.2023.124627?view=FULL
# Downloaded: Cross_Document_Linking/XML/10.1016_j.ijbiomac.2023.124627.xml
# Requesting: https://api.elsevier.com/content/article/doi/10.1039%2Fc7cc00737j?view=FULL
# DOI not found: 10.1039/c7cc00737j (Status: 404)
# Requesting: https://api.elsevier.com/content/article/doi/10.1016%2Fj.jwpe.2020.101670?view=FULL
# Downloaded: Cross_Document_Linking/XML/10.1016_j.jwpe.2020.101670.xml
# Requesting: https://api.elsevier.com/content/article/doi/10.1021%2Facsanm.8b01283?view=FULL
# DOI not found: 10.1021/acsanm.8b01283 (Status: 404)
# Requesting: https://api.elsevier.com/content/article/doi/10.1002%2Fghg.2204?view=FULL
# DOI not found: 10.1002/ghg.2204 (Status: 404)
# Requesting: https://api.elsevier.com/content/article/doi/10.1016%2Fj.apt.2022.103701?view=FULL
# Downloaded: Cross_Document_Linking/XML/10.1016_j.apt.2022.103701.xml
# Requesting: https://api.elsevier.com/content/article/doi/10.1016%2Fj.cej.2020.127396?view=FULL
# Downloaded: Cross_Document_Linking/XML/10.1016_j.cej.2020.127396.xml
# Requesting: https://api.elsevier.com/content/article/doi/10.1039%2Fd4nj01657b?view=FULL
# DOI not found: 10.1039/d4nj01657b (Status: 404)
# Requesting: https://api.elsevier.com/content/article/doi/10.1016%2Fj.inoche.2020.107975?view=FULL
# Downloaded: Cross_Document_Linking/XML/10.1016_j.inoche.2020.107975.xml
# Requesting: https://api.elsevier.com/content/article/doi/10.1016%2Fj.ultsonch.2016.06.011?view=FULL
# Downloaded: Cross_Document_Linking/XML/10.1016_j.ultsonch.2016.06.011.xml
# Requesting: https://api.elsevier.com/content/article/doi/10.3390%2Fcatal9040338?view=FULL
# DOI not found: 10.3390/catal9040338 (Status: 404)
# Requesting: https://api.elsevier.com/content/article/doi/10.1007%2Fs10967-022-08510-y?view=FULL
# DOI not found: 10.1007/s10967-022-08510-y (Status: 404)
# Requesting: https://api.elsevier.com/content/article/doi/10.1039%2Fd3nj05614g?view=FULL
# DOI not found: 10.1039/d3nj05614g (Status: 404)
# Requesting: https://api.elsevier.com/content/article/doi/10.1039%2Fc8ra07143h?view=FULL
# DOI not found: 10.1039/c8ra07143h (Status: 404)
# Requesting: https://api.elsevier.com/content/article/doi/10.1016%2Fj.matlet.2020.128127?view=FULL
# Downloaded: Cross_Document_Linking/XML/10.1016_j.matlet.2020.128127.xml
# Requesting: https://api.elsevier.com/content/article/doi/10.1039%2Fd4gc02189d?view=FULL
# DOI not found: 10.1039/d4gc02189d (Status: 404)
# Requesting: https://api.elsevier.com/content/article/doi/10.1021%2Facsami.6b16817?view=FULL
# DOI not found: 10.1021/acsami.6b16817 (Status: 404)
# Requesting: https://api.elsevier.com/content/article/doi/10.1016%2Fj.colsurfa.2022.129750?view=FULL
# Downloaded: Cross_Document_Linking/XML/10.1016_j.colsurfa.2022.129750.xml
# Requesting: https://api.elsevier.com/content/article/doi/10.1002%2
xml
# Requesting: https://api.elsevier.com/content/article/doi/10.1016%2Fj.chemosphere.2019.125423?view=FULL
# Downloaded: Cross_Document_Linking/XML/10.1016_j.chemosphere.2019.125423.xml
# Requesting: https://api.elsevier.com/content/article/doi/10.1021%2Fjacs.6b05261?view=FULL
# DOI not found: 10.1021/jacs.6b05261 (Status: 404)
# Requesting: https://api.elsevier.com/content/article/doi/10.1039%2Fd5ta00031a?view=FULL
# DOI not found: 10.1039/d5ta00031a (Status: 404)
# Requesting: https://api.elsevier.com/content/article/doi/10.1016%2Fj.apmt.2020.100604?view=FULL
# Downloaded: Cross_Document_Linking/XML/10.1016_j.apmt.2020.100604.xml
# Requesting: https://api.elsevier.com/content/article/doi/10.1002%2Fejic.201600338?view=FULL
# DOI not found: 10.1002/ejic.201600338 (Status: 404)
# Requesting: https://api.elsevier.com/content/article/doi/10.1002%2Fsmll.202101475?view=FULL
# DOI not found: 10.1002/smll.202101475 (Status: 404)
# Requesting: https://api.elsevier.com/content/article/doi/10.1039%2Fc6nj03912j?view=FULL
# DOI not found: 10.1039/c6nj03912j (Status: 404)
# Requesting: https://api.elsevier.com/content/article/doi/10.1007%2Fs10853-024-09430-w?view=FULL
# DOI not found: 10.1007/s10853-024-09430-w (Status: 404)
# Requesting: https://api.elsevier.com/content/article/doi/10.1007%2Fs11051-020-04855-1?view=FULL
# DOI not found: 10.1007/s11051-020-04855-1 (Status: 404)
# Requesting: https://api.elsevier.com/content/article/doi/10.1016%2Fj.bios.2016.10.006?view=FULL
# Downloaded: Cross_Document_Linking/XML/10.1016_j.bios.2016.10.006.xml
# Requesting: https://api.elsevier.com/content/article/doi/10.1016%2Fj.jcis.2022.02.062?view=FULL
# Downloaded: Cross_Document_Linking/XML/10.1016_j.jcis.2022.02.062.xml
# Requesting: https://api.elsevier.com/content/article/doi/10.1021%2Facs.cgd.7b00102?view=FULL
# DOI not found: 10.1021/acs.cgd.7b00102 (Status: 404)
# Requesting: https://api.elsevier.com/content/article/doi/10.3303%2FCET24111097?view=FULL
# DOI not found: 10.3303/CET24111097 (Status: 404)
# Requesting: https://api.elsevier.com/content/article/doi/10.13208%2Fj.electrochem.160201?view=FULL
# DOI not found: 10.13208/j.electrochem.160201 (Status: 404)
# Requesting: https://api.elsevier.com/content/article/doi/10.1016%2Fj.jcis.2022.09.120?view=FULL
# Downloaded: Cross_Document_Linking/XML/10.1016_j.jcis.2022.09.120.xml
# Requesting: https://api.elsevier.com/content/article/doi/10.1021%2Facsnano.0c06221?view=FULL
# DOI not found: 10.1021/acsnano.0c06221 (Status: 404)
# Requesting: https://api.elsevier.com/content/article/doi/10.1021%2Facs.iecr.8b06017?view=FULL
# DOI not found: 10.1021/acs.iecr.8b06017 (Status: 404)
# Requesting: https://api.elsevier.com/content/article/doi/10.1016%2Fj.snb.2019.04.062?view=FULL
# Downloaded: Cross_Document_Linking/XML/10.1016_j.snb.2019.04.062.xml
# Requesting: https://api.elsevier.com/content/article/doi/10.1007%2Fs12127-020-00263-2?view=FULL
# DOI not found: 10.1007/s12127-020-00263-2 (Status: 404)
# Requesting: https://api.elsevier.com/content/article/doi/10.1016%2Fj.jhazmat.2024.136859?view=FULL
# Downloaded: Cross_Document_Linking/XML/10.1016_j.jhazmat.2024.136859.xml
# Requesting: https://api.elsevier.com/content/article/doi/10.1016%2Fj.jenvrad.2023.107211?view=FULL
# Downloaded: Cross_Document_Linking/XML/10.1016_j.jenvrad.2023.107211.xml
# Requesting: https://api.elsevier.com/content/article/doi/10.1039%2Fd4nj04912h?view=FULL
# DOI not found: 10.1039/d4nj04912h (Status: 404)
# Requesting: https://api.elsevier.com/content/article/doi/10.1039%2Fd2ra05036f?view=FULL
# DOI not found: 10.1039/d2ra05036f (Status: 404)
# Requesting: https://api.elsevier.com/content/article/doi/10.1021%2Facsami.1c16479?view=FULL
# DOI not found: 10.1021/acsami.1c16479 (Status: 404)
# Requesting: https://api.elsevier.com/content/article/doi/10.1016%2Fj.jpcs.2022.111094?view=FULL
# Downloaded: Cross_Document_Linking/XML/10.1016_j.jpcs.2022.111094.xml
# Requesting: https://api.elsevier.com/content/article/doi/10.1016%2Fj.hazl.2023.100094?view=FULL
# Downloaded: Cross_Document_Linking/XML/10.1016_j.hazl.2023.100094.xml
# Requesting: https://api.elsevier.com/content/article/doi/10.1016%2Fj.apsb.2024.03.014?view=FULL
# Downloaded: Cross_Document_Linking/XML/10.1016_j.apsb.2024.03.014.xml
# Requesting: https://api.elsevier.com/content/article/doi/10.1016%2Fj.memsci.2020.118412?view=FULL
# Downloaded: Cross_Document_Linking/XML/10.1016_j.memsci.2020.118412.xml
# Requesting: https://api.elsevier.com/content/article/doi/10.1039%2Fd5cc00529a?view=FULL
# DOI not found: 10.1039/d5cc00529a (Status: 404)
# Requesting: https://api.elsevier.com/content/article/doi/10.11203%2Fjar.34.5?view=FULL
# DOI not found: 10.11203/jar.34.5 (Status: 404)
# Requesting: https://api.elsevier.com/content/article/doi/10.1016%2Fj.chemosphere.2016.02.005?view=FULL
# Downloaded: Cross_Document_Linking/XML/10.1016_j.chemosphere.2016.02.005.xml
#
# Summary: 193 successful, 301 not found, 1 errors
# {'success': 193, 'not_found': 301, 'error': 1}

# %% [markdown]
# Now we have to remove all the papers that failed to download from the "relevant_papers_df"

# %%
# Get list of all filenames in the save_path directory
save_path_files = set(os.listdir(save_path))

# Define a function to check if the corresponding XML file exists
def doi_in_save_path(doi):
    filename = doi.replace('/', '_') + '.xml'
    return filename in save_path_files

# Filter the DataFrame
relevant_papers_df = relevant_papers_df[relevant_papers_df['doi'].apply(doi_in_save_path)].reset_index(drop=True)
relevant_papers_df
# Out:
#                                                  title  \
# 0    Direct synthesis of Al-HKUST-1 and its applica...
# 1    High efficiency synthesis of HKUST-1 under mil...
# 2    Sonoelectrochemical synthesis of metal-organic...
# 3    Scalable continuous production of high quality...
# 4    Optimized synthesis of nano-scale high quality...
# ..                                                 ...
# 188  Synthesis of core-double-shell structured Fe<i...
# 189  Recent advances of Copper- BTC metal-organic f...
# 190  An antibiotic-free platform for eliminating pe...
# 191  Precise assembly of a zeolite imidazolate fram...
# 192  Adsorption of silver nanoparticles from aqueou...
#
#                                               abstract  \
# 0    Direct synthesis of Al-HKUST-1 was successfull...
# 1    This study focuses on the development of a hyd...
# 2    Here we report a new synergic strategy for the...
# 3    Metal Organic Frameworks (MOFs) are materials ...
# 4    This study was focused on the development of a...
# ..                                                 ...
# 188  Organic dyes have complex and relatively stabl...
# 189  Water borne emerging pollutants represents a s...
# 190  Helicobacter pylori (H. pylori) infection rema...
# 191  Polypropylene (PP) has been widely used in the...
# 192  Silver nanoparticles (AgNP) are emerging pollu...
#
#                                    doi MOF Name
# 0         10.1016/j.nanoso.2021.100773  HKUST-1
# 1           10.1016/j.pnsc.2018.08.002  HKUST-1
# 2       10.1016/j.synthmet.2016.07.003  HKUST-1
# 3            10.1016/j.cej.2017.05.169  HKUST-1
# 4      10.1016/j.micromeso.2018.05.027  HKUST-1
# ..                                 ...      ...
# 188         10.1016/j.jpcs.2022.111094  HKUST-1
# 189         10.1016/j.hazl.2023.100094  HKUST-1
# 190         10.1016/j.apsb.2024.03.014  HKUST-1
# 191       10.1016/j.memsci.2020.118412  HKUST-1
# 192  10.1016/j.chemosphere.2016.02.005  HKUST-1
#
# [193 rows x 4 columns]

# %% [markdown]
# <b>Synthesis Procedure Extractions</b>
#
# Follows same steps as the synthesis extraction notebook (``ChemUnity_Synthesis.ipynb``)

# %%
llm = ChatOpenAI(model="gpt-4o", temperature=0.1)
parser_llm = ChatOpenAI(model="gpt-4o-mini", temperature=0)
agent = ExtractionAgent(llm=llm)
input_folder = "Cross_Document_Linking/XML"

# %%
# Directory and file paths
results_dir = os.path.join(input_folder, 'synthesis_results')
results_file = os.path.join(results_dir, 'synthesis_extractions.csv')

# Set parameters
saving_every = 50  # Save results every X MOFs
batch_size = 4000    # Stop after processing X MOFs (manual restart required)

# Ensure the results directory exists
os.makedirs(results_dir, exist_ok=True)

# Prepare or load the results DataFrame
if os.path.exists(results_file):
    existing_results = pd.read_csv(results_file)

    # Drop "Unnamed: 0" if it exists
    if "Unnamed: 0" in existing_results.columns:
        existing_results = existing_results.drop(columns=["Unnamed: 0"])
    
    processed_refs = set(existing_results["Reference"])
    results = existing_results.to_dict(orient="list")
else:
    processed_refs = set()
    results = {
        "Metal Precursor": [], "Linker": [], "Solvent": [],
        "Temperature": [], "Reaction Time": [], "Reaction Type": [], "Synthesis Procedure": [],
        "Additional Conditions": [], "Justification": [], "Reference": [],
        "MOF Name": []
    }

# Determine rows that haven't been processed yet
remaining_df = relevant_papers_df[~relevant_papers_df["doi"].isin(processed_refs)].reset_index(drop=True)

# Get the total number of MOFs that need to be processed
total_remaining = len(remaining_df)
total_processed = 0  # Tracks how many MOFs have been processed in this run

# %%
# Process in batches, but stop after processing batch_size MOFs
for batch_start in range(0, total_remaining, saving_every):
    if total_processed >= batch_size:
        break  # Stop execution when batch_size MOFs are processed

    batch_df = remaining_df.iloc[batch_start:batch_start + saving_every]
    
    # Track number of rows before processing this batch
    prev_length = len(results["Reference"])

    # Process each row in the batch
    for i, row in batch_df.iterrows():
        reference = row["doi"]
        mof = row["MOF Name"]
        
        # Generate file name based on reference
        file_name = os.path.join(input_folder, reference.replace("/", "_") + ".xml")
        print(file_name)
        
        # Get synthesis extraction via agent response
        try:
            response = agent.agent_response(mof, file_name,
                                            SYNTHESIS_EXTRACTION, CoV=False, filtered=False,
                                            gen_extraction_structure=Synthesis,
                                            )
            synthesis_extraction = response

            # Append extracted synthesis data to results dictionary
            results["Metal Precursor"].append(getattr(synthesis_extraction, "metal_precursor", ""))
            results["Linker"].append(getattr(synthesis_extraction, "organic_linker", ""))
            results["Solvent"].append(getattr(synthesis_extraction, "solvent", ""))
            results["Temperature"].append(getattr(synthesis_extraction, "temperature", ""))
            results["Reaction Type"].append(getattr(synthesis_extraction, "reaction_type", ""))
            results["Reaction Time"].append(getattr(synthesis_extraction, "reaction_time", ""))
            results["Synthesis Procedure"].append(getattr(synthesis_extraction, "synthesis_procedure", ""))
            results["Additional Conditions"].append(getattr(synthesis_extraction, "additional_conditions", ""))
            results["Justification"].append(getattr(synthesis_extraction, "justification", ""))
            results["Reference"].append(reference)
            results["MOF Name"].append(mof)
            
            total_processed += 1  # Increment the count of processed MOFs
            
            # Stop early if batch_size limit is reached
            if total_processed >= batch_size:
                break  

        except Exception as e:
            print(f"Error processing row {i} with DOI {reference}: {e}")

    # Save progress every `saving_every` MOFs
    batch_results_df = pd.DataFrame(results)
    batch_results_df.to_csv(results_file, index=False)

    # Calculate remaining MOFs
    # Correct calculation of remaining MOFs
    remaining_to_process = max(total_remaining - total_processed, 0)

    print(f"✅ {total_processed} MOFs processed so far. {remaining_to_process} remaining this batch. Progress saved to {results_file}.")

# Final completion message
if total_processed >= batch_size:
    print(f"🚫 Processing stopped after {batch_size} MOFs. {remaining_to_process} MOFs still need processing. Restart script to continue.")
else:
    print("✅ Processing complete! All MOFs processed.")
# Out:
# Cross_Document_Linking/XML/10.1016_j.nanoso.2021.100773.xml
# Detected Elsevier XML format in 'Cross_Document_Linking/XML/10.1016_j.nanoso.2021.100773.xml'
# Converted 'Cross_Document_Linking/XML/10.1016_j.nanoso.2021.100773.xml' to Markdown at 'Cross_Document_Linking/MD/10.1016_j.nanoso.2021.100773.md'
# Action: reading the document
# finding all properties of name 1: HKUST-1
#
# Result:
# - Metal Precursor: Cu(NO3)2.3H2O
# - Organic Linker: H3BTC (1,3,5-benzenetricarboxylic acid)
# - Solvent: Ethanol, DMF (dimethylformamide) in a ratio of 1:1, demineralized water
# - Temperature: 100 °C
# - Reaction Type: Solvothermal
# - Reaction Time: 10 hours
# - Synthesis Procedure:
#   - Dissolve 1 g of H3BTC in 30 mL of a mixture of ethanol and DMF with a ratio of 1:1.
#   - In a separate container, dissolve 2.0772 g of Cu(NO3)2.3H2O in 15 mL of demineralized water.
#   - Mix both solutions and stir using a magnetic stirrer until a homogeneous solution is obtained.
#   - Carry out a solvothermal process in an oven at 100 °C for 10 hours in a sealed reaction bottle.
#   - Cool the solution at room temperature for 24 hours.
#   - Rinse the solution using a DMF solution for 24 hours and methanol for 72 hours in an oil bath at 50—55 °C, replacing both the DMF and the methanol every 24 hours.
#   - Obtain a blue colored HKUST-1 powder at the end of the process.
# - Additional Conditions: Not Provided
# - Justification: "HKUST-1 synthesis was performed based on the research carried out by Chowdurry et al. [24] and our previous research [25]. 1 g of H3BTC was dissolved in 30 mL mixture of ethanol and DMF with a ratio of 1:1. In a separate container, 2.0772 g of Cu(NO3)2.3H2O was dissolved into 15 mL of demineralized water. Both solutions were mixed and stirred using a magnetic stirrer until a homogeneous solution was obtained. Next, a solvothermal process was carried out in an oven at 100 °C for 10 h in a sealed reaction bottle before being cooled at room temperature for 24 h. The solution was consequently rinsed using a DMF solution for 24 h and methanol for 72 h in an oil bath at 50—55 °C, with both the DMF and the methanol being replaced every 24 h. A blue colored HKUST-1 powder should be obtained at the end of the process."
#
# Parsed Result:
# Metal Precursor: Cu(NO3)2.3H2O
# Organic Linker: H3BTC (1,3,5-benzenetricarboxylic acid)
# Solvent: Ethanol, DMF (dimethylformamide) in a ratio of 1:1, demineralized water
# Temperature: 100 °C
# Reaction Type: Solvothermal
# Reaction Time: 10 hours
# Summarized Procedure: Dissolve 1 g of H3BTC in 30 mL of a mixture of ethanol and DMF with a ratio of 1:1. In a separate container, dissolve 2.0772 g of Cu(NO3)2.3H2O in 15 mL of demineralized water. Mix both solutions and stir using a magnetic stirrer until a homogeneous solution is obtained. Carry out a solvothermal process in an oven at 100 °C for 10 hours in a sealed reaction bottle. Cool the solution at room temperature for 24 hours. Rinse the solution using a DMF solution for 24 hours and methanol for 72 hours in an oil bath at 50—55 °C, replacing both the DMF and the methanol every 24 hours. Obtain a blue colored HKUST-1 powder at the end of the process.
# Additional Conditions: Not Provided
# Exact Sentences: HKUST-1 synthesis was performed based on the research carried out by Chowdurry et al. [24] and our previous research [25]. 1 g of H3BTC was dissolved in 30 mL mixture of ethanol and DMF with a ratio of 1:1. In a separate container, 2.0772 g of Cu(NO3)2.3H2O was dissolved into 15 mL of demineralized water. Both solutions were mixed and stirred using a magnetic stirrer until a homogeneous solution was obtained. Next, a solvothermal process was carried out in an oven at 100 °C for 10 h in a sealed reaction bottle before being cooled at room temperature for 24 h. The solution was consequently rinsed using a DMF solution for 24 h and methanol for 72 h in an oil bath at 50—55 °C, with both the DMF and the methanol being replaced every 24 h. A blue colored HKUST-1 powder should be obtained at the end of the process.
#
#
# Cross_Document_Linking/XML/10.1016_j.pnsc.2018.08.002.xml
# Detected Elsevier XML format in 'Cross_Document_Linking/XML/10.1016_j.pnsc.2018.08.002.xml'
# Converted 'Cross_Document_Linking/XML/10.1016_j.pnsc.2018.08.002.xml' to Markdown at 'Cross_Document_Linking/MD/10.1016_j.pnsc.2018.08.002.md'
# Action: reading the document
# finding all properties of name 1: HKUST-1
#
# Result:
# - Metal Precursor: Copper nitrate trihydrate
# - Organic Linker: Benzene-1,3,5-tricarboxylic acid (BTC)
# - Solvent: Not Provided
# - Temperature: 50 °C
# - Reaction Type: Solvothermal
# - Reaction Time: 3 hours
# - Synthesis Procedure:
#   - Copper nitrate trihydrate and benzene-1,3,5-tricarboxylic acid were mixed.
#   - The mixture was heated to 50 °C for 3 hours.
#   - Upon cooling to room temperature, the mixture was placed in a dryer operated at 120 °C for 12 hours.
#   - The dried powder was activated by washing with either methanol or ethanol to remove impurities.
#   - The product was centrifuged and dried at 120 °C.
# - Additional Conditions: Atmospheric pressure
# - Justification: "In a typical synthesis process, copper nitrate trihydrate (98%) and benzene-1,3,5-tricarboxylic acid (95%) were mixed and heated to 50 °C for 3 h. Upon cooling to room temperature, it was placed in a dryer operated at 120 °C for 12 h. The dried powder was then activated by using either methanol or ethanol to wash out the impurities trapped in pores. Finally, the product was centrifuged and dried at 120 °C."
#
# Parsed Result:
# Metal Precursor: Copper nitrate trihydrate
# Organic Linker: Benzene-1,3,5-tricarboxylic acid (BTC)
# Solvent: Not Provided
# Temperature: 50 °C
# Reaction Type: Solvothermal
# Reaction Time: 3 hours
# Summarized Procedure: Copper nitrate trihydrate and benzene-1,3,5-tricarboxylic acid were mixed. The mixture was heated to 50 °C for 3 hours. Upon cooling to room temperature, the mixture was placed in a dryer operated at 120 °C for 12 hours. The dried powder was activated by washing with either methanol or ethanol to remove impurities. The product was centrifuged and dried at 120 °C.
# Additional Conditions: Atmospheric pressure
# Exact Sentences: In a typical synthesis process, copper nitrate trihydrate (98%) and benzene-1,3,5-tricarboxylic acid (95%) were mixed and heated to 50 °C for 3 h. Upon cooling to room temperature, it was placed in a dryer operated at 120 °C for 12 h. The dried powder was then activated by using either methanol or ethanol to wash out the impurities trapped in pores. Finally, the product was centrifuged and dried at 120 °C.
#
#
# Cross_Document_Linking/XML/10.1016_j.synthmet.2016.07.003.xml
# Detected Elsevier XML format in 'Cross_Document_Linking/XML/10.1016_j.synthmet.2016.07.003.xml'
# Converted 'Cross_Document_Linking/XML/10.1016_j.synthmet.2016.07.003.xml' to Markdown at 'Cross_Document_Linking/MD/10.1016_j.synthmet.2016.07.003.md'
# Action: reading the document
# finding all properties of name 1: HKUST-1
#
# Result:
# - Metal Precursor: Copper wire (Cu)
# - Organic Linker: BTC (1,3,5-benzenetricarboxylic acid)
# - Solvent: Dimethylformamide (DMF)/H2O (1:1, v/v)
# - Temperature: Not Provided
# - Reaction Type: Sonoelectrochemical
# - Reaction Time: Not Provided
# - Synthesis Procedure:
#   - Dissolve NaNO3 and 1,3,5-benzenetricarboxylic acid in a mixture of DMF/H2O solvents (1:1, v/v).
#   - Place the resulting solution into a single-compartment electrochemical cell with two copper electrodes partially immersed.
#   - Apply an electrical potential difference between the electrodes to initiate the process of anodic dissolution.
#   - Keep the solution under ultrasonic irradiation to ensure the expected synergic effect.
#   - Allow the formation of a blue precipitate (HKUST-1).
#   - Wash all products with water (2×), ethanol/acetone 1:1 (3×) and then dry at room temperature.
# - Additional Conditions:
#   - Electrical potential difference: 12V
#   - Ultrasound frequency: 20KHz, 30 and 60% of power
# - Justification: "In a typical process, NaNO3 (0.24molL−1) and 1,3,5-Benzenetricarboxylic acid (24 and 48mmolL−1) were dissolved in a mixture of DMF/H2O solvents (1:1, v/v). The resulting solution placed into a single-compartment electrochemical cell with two copper electrodes partially immersed. An electrical potential difference was applied between the electrodes, initiating the process of anodic dissolution (Cu0 (aq) ⇌Cu2+(aq)+2e−), while the solution was kept under ultrasonic irradiation to ensure the expected synergic effect. This process, together with the deprotonation of trimesic acid (H3BTC(aq) +3 DMF(aq)⇌ BTC3− (aq) +3 HDMF+ (aq)) allowed the formation of a blue precipitate (HKUST-1)."
#
# Parsed Result:
# Metal Precursor: Copper wire (Cu)
# Organic Linker: BTC (1,3,5-benzenetricarboxylic acid)
# Solvent: Dimethylformamide (DMF)/H2O (1:1, v/v)
# Temperature: Not Provided
# Reaction Type: Sonoelectrochemical
# Reaction Time: Not Provided
# Summarized Procedure: Dissolve NaNO3 and 1,3,5-benzenetricarboxylic acid in a mixture of DMF/H2O solvents (1:1, v/v). Place the resulting solution into a single-compartment electrochemical cell with two copper electrodes partially immersed. Apply an electrical potential difference between the electrodes to initiate the process of anodic dissolution. Keep the solution under ultrasonic irradiation to ensure the expected synergic effect. Allow the formation of a blue precipitate (HKUST-1). Wash all products with water (2×), ethanol/acetone 1:1 (3×) and then dry at room temperature.
# Additional Conditions: Electrical potential difference: 12V; Ultrasound frequency: 20KHz, 30 and 60% of power
# Exact Sentences: In a typical process, NaNO3 (0.24molL−1) and 1,3,5-Benzenetricarboxylic acid (24 and 48mmolL−1) were dissolved in a mixture of DMF/H2O solvents (1:1, v/v). The resulting solution placed into a single-compartment electrochemical cell with two copper electrodes partially immersed. An electrical potential difference was applied between the electrodes, initiating the process of anodic dissolution (Cu0 (aq) ⇌Cu2+(aq)+2e−), while the solution was kept under ultrasonic irradiation to ensure the expected synergic effect. This process, together with the deprotonation of trimesic acid (H3BTC(aq) +3 DMF(aq)⇌ BTC3− (aq) +3 HDMF+ (aq)) allowed the formation of a blue precipitate (HKUST-1).
#
#
# Cross_Document_Linking/XML/10.1016_j.cej.2017.05.169.xml
# Detected Elsevier XML format in 'Cross_Document_Linking/XML/10.1016_j.cej.2017.05.169.xml'
# Converted 'Cross_Document_Linking/XML/10.1016_j.cej.2017.05.169.xml' to Markdown at 'Cross_Document_Linking/MD/10.1016_j.cej.2017.05.169.md'
# Action: reading the document
# finding all properties of name 1: HKUST-1
#
# Result:
# - Metal Precursor: Copper nitrate hemipentahydrate
# - Organic Linker: Trimesic acid (1,3,5-benzenetricarboxylic acid)
# - Solvent: Ethanol, DMF/Water/Ethanol
# - Temperature: 60°C, 79°C
# - Reaction Type: Solvothermal, Microwave assisted
# - Reaction Time: 5 hours (batch), 13 seconds to 5 minutes (continuous microwave)
# - Synthesis Procedure:
#   - For batch synthesis:
#     - Mix copper nitrate hemipentahydrate and trimesic acid in a solvent system of DMF, water, and ethanol or ethanol only.
#     - Stir the solution magnetically and heat using an oil bath to reach the desired temperature.
#     - Cap the sample vials and place them into the oil bath, preheated under constant stirring to the reaction temperature.
#     - Remove samples at preselected time intervals for analysis.
#   - For continuous synthesis:
#     - Use a continuous stirred tank reactor (CSTR) with ethanol as the solvent.
#     - Maintain the reaction temperature at 79°C.
#     - Increase reactant concentrations to study effects on yield and surface area.
#     - For microwave-assisted synthesis, use a domestic microwave oven with a recycle loop for continuous operation.
#     - Pump the reaction solution through the microwave cavity, maintaining a residence time of 5 minutes or as low as 13 seconds.
#     - Monitor the output temperature and adjust microwave power to prevent overheating.
# - Additional Conditions:
#   - For microwave synthesis, maintain microwave power at approximately 80W.
#   - Ensure complete dissolution of reactants before initiating the reaction.
#   - Use a peristaltic pump to control flow rates in continuous systems.
# - Justification:
#   - "All batch tests were performed using 6mL of total solvent volume and a metal:ligand (M:L) concentration ratio of 1.88:1, resulting in the metal being in excess (1.5:1 is the stoichiometric ratio)."
#   - "The solution was composed of equal parts in volume of N,N-dimethyl formamide (DMF) (Sigma Aldrich, 99.8%, anhydrous), deionised water and ethanol (Sigmas Aldrich, 99%). 0.231g copper nitrate hemipentahydrate (Sigma Aldrich, 98%) and 0.111g trimesic acid (Sigma Aldrich, 95%) were added to the solution (solids content of about 3% by mass)."
#   - "The ethanol experiment was then repeated at a reaction temperature of 79°C."
#   - "Using a domestic microwave oven, Logik L20MS10 (800W), we investigated the main parameters affecting the production of HKUST-1 using microwave heating rather than conventional convective heating."
#   - "The resulting solution was pumped through the tubing within the microwave cavity at a rate of 300mLh−1, giving a residence time of 5min."
#   - "When increasing the flowrate to 550mLh−1, from 300mLh−1, and decreasing the reactor volume to 2mL from the original 25mL, the residence time was reduced from 5min to 13s."
#
# Parsed Result:
# Metal Precursor: Copper nitrate hemipentahydrate
# Organic Linker: Trimesic acid (1,3,5-benzenetricarboxylic acid)
# Solvent: Ethanol, DMF/Water/Ethanol
# Temperature: 60°C, 79°C
# Reaction Type: Solvothermal, Microwave assisted
# Reaction Time: 5 hours (batch), 13 seconds to 5 minutes (continuous microwave)
# Summarized Procedure: For batch synthesis: Mix copper nitrate hemipentahydrate and trimesic acid in a solvent system of DMF, water, and ethanol or ethanol only. Stir the solution magnetically and heat using an oil bath to reach the desired temperature. Cap the sample vials and place them into the oil bath, preheated under constant stirring to the reaction temperature. Remove samples at preselected time intervals for analysis. For continuous synthesis: Use a continuous stirred tank reactor (CSTR) with ethanol as the solvent. Maintain the reaction temperature at 79°C. Increase reactant concentrations to study effects on yield and surface area. For microwave-assisted synthesis, use a domestic microwave oven with a recycle loop for continuous operation. Pump the reaction solution through the microwave cavity, maintaining a residence time of 5 minutes or as low as 13 seconds. Monitor the output temperature and adjust microwave power to prevent overheating.
# Additional Conditions: For microwave synthesis, maintain microwave power at approximately 80W. Ensure complete dissolution of reactants before initiating the reaction. Use a peristaltic pump to control flow rates in continuous systems.
# Exact Sentences: "All batch tests were performed using 6mL of total solvent volume and a metal:ligand (M:L) concentration ratio of 1.88:1, resulting in the metal being in excess (1.5:1 is the stoichiometric ratio)." "The solution was composed of equal parts in volume of N,N-dimethyl formamide (DMF) (Sigma Aldrich, 99.8%, anhydrous), deionised water and ethanol (Sigmas Aldrich, 99%). 0.231g copper nitrate hemipentahydrate (Sigma Aldrich, 98%) and 0.111g trimesic acid (Sigma Aldrich, 95%) were added to the solution (solids content of about 3% by mass)." "The ethanol experiment was then repeated at a reaction temperature of 79°C." "Using a domestic microwave oven, Logik L20MS10 (800W), we investigated the main parameters affecting the production of HKUST-1 using microwave heating rather than conventional convective heating." "The resulting solution was pumped through the tubing within the microwave cavity at a rate of 300mLh−1, giving a residence time of 5min." "When increasing the flowrate to 550mLh−1, from 300mLh−1, and decreasing the reactor volume to 2mL from the original 25mL, the residence time was reduced from 5min to 13s."
#
#
# Cross_Document_Linking/XML/10.1016_j.micromeso.2018.05.027.xml
# Detected Elsevier XML format in 'Cross_Document_Linking/XML/10.1016_j.micromeso.2018.05.027.xml'
# Converted 'Cross_Document_Linking/XML/10.1016_j.micromeso.2018.05.027.xml' to Markdown at 'Cross_Document_Linking/MD/10.1016_j.micromeso.2018.05.027.md'
# Action: reading the document
# finding all properties of name 1: HKUST-1
#
# Result:
# - Metal Precursor: Copper nitrate trihydrate
# - Organic Linker: TMA (trimesic acid)
# - Solvent: Deionized water, Ethanol
# - Temperature: 85 °C
# - Reaction Type: Hydro/solvo-thermal
# - Reaction Time: 3 hours
# - Synthesis Procedure:
#   - Dissolve 0.03 mol of copper nitrate trihydrate in 250 mL of deionized water to form Solution A.
#   - Add 0.02 mol of trimesic acid (TMA) and 0.06 mol Triethylamine (TEA) in 250 mL of ethanol to form Solution B.
#   - Mix Solutions A and B and heat under constant stirring to 85 °C.
#   - Maintain the temperature isothermally for 3 hours.
#   - Cool the solution to room temperature in an ice bath.
#   - Centrifuge to produce pristine HKUST-1.
#   - Activate the HKUST-1 using slurry state activation, powder state activation, or slurry-powder state activation to remove internal impurities.
#   - Use ethanol or methanol as activation agents in a reflux condenser.
#   - Conduct the activation process for 3 hours.
#   - Centrifuge the activated solution to obtain precipitation and dry at 120 °C to obtain final HKUST-1 powder.
# - Additional Conditions: The molar ratio of TEA, Cu2+, and TMA is 6:3:2. The activation process involves using 62.5 mL of ethanol or methanol per gram of pristine HKUST-1.
# - Justification: "Firstly, 0.03 mol of copper nitrate trihydrate (Sigma Aldrich, 98%) was dissolved in a 250 mL of deionized water to form Solution A, while 0.02 mol of trimesic acid (TMA) (Sigma Aldrich, 95%) and 0.06 mol Triethylamine (TEA) (Sigma Aldrich, 99.8%, anhydrous) were added in a 250 mL of ethanol (Sigma Aldrich, 99%) to form Solution B. These two solutions were then mixed and heated under constant stirring to the pre-set temperature level, i.e., 25, 50, 75, 80, 85 °C, and kept isothermal for a period of time (3, 6 or 9 h). The solution was then cooled down to room temperature in an ice bath and centrifuged to produce pristine HKUST-1, which was activated using slurry state activation, powder state activation or slurry-powder state activation to remove internal impurities."
#
# Parsed Result:
# Metal Precursor: Copper nitrate trihydrate
# Organic Linker: TMA (trimesic acid)
# Solvent: Deionized water, Ethanol
# Temperature: 85 °C
# Reaction Type: Hydro/solvo-thermal
# Reaction Time: 3 hours
# Summarized Procedure: Dissolve 0.03 mol of copper nitrate trihydrate in 250 mL of deionized water to form Solution A. Add 0.02 mol of trimesic acid (TMA) and 0.06 mol Triethylamine (TEA) in 250 mL of ethanol to form Solution B. Mix Solutions A and B and heat under constant stirring to 85 °C. Maintain the temperature isothermally for 3 hours. Cool the solution to room temperature in an ice bath. Centrifuge to produce pristine HKUST-1. Activate the HKUST-1 using slurry state activation, powder state activation, or slurry-powder state activation to remove internal impurities. Use ethanol or methanol as activation agents in a reflux condenser. Conduct the activation process for 3 hours. Centrifuge the activated solution to obtain precipitation and dry at 120 °C to obtain final HKUST-1 powder.
# Additional Conditions: The molar ratio of TEA, Cu2+, and TMA is 6:3:2. The activation process involves using 62.5 mL of ethanol or methanol per gram of pristine HKUST-1.
# Exact Sentences: Firstly, 0.03 mol of copper nitrate trihydrate (Sigma Aldrich, 98%) was dissolved in a 250 mL of deionized water to form Solution A, while 0.02 mol of trimesic acid (TMA) (Sigma Aldrich, 95%) and 0.06 mol Triethylamine (TEA) (Sigma Aldrich, 99.8%, anhydrous) were added in a 250 mL of ethanol (Sigma Aldrich, 99%) to form Solution B. These two solutions were then mixed and heated under constant stirring to the pre-set temperature level, i.e., 25, 50, 75, 80, 85 °C, and kept isothermal for a period of time (3, 6 or 9 h). The solution was then cooled down to room temperature in an ice bath and centrifuged to produce pristine HKUST-1, which was activated using slurry state activation, powder state activation or slurry-powder state activation to remove internal impurities.
#
#
# Cross_Document_Linking/XML/10.1016_S1872-2067(17)62874-2.xml
# Detected Elsevier XML format in 'Cross_Document_Linking/XML/10.1016_S1872-2067(17)62874-2.xml'
# Converted 'Cross_Document_Linking/XML/10.1016_S1872-2067(17)62874-2.xml' to Markdown at 'Cross_Document_Linking/MD/10.1016_S1872-2067(17)62874-2.md'
# Action: reading the document
# finding all properties of name 1: HKUST-1
#
# Result:
# - Metal Precursor: Copper rod (purity = 99.9998%)
# - Organic Linker: H3BTC (1,3,5-benzenetricarboxylic acid)
# - Solvent: Ethanol/water (3:1)
# - Temperature: Not Provided
# - Reaction Type: Electrochemical, Solvothermal
# - Reaction Time: 3 hours (Electrochemical), 12 hours (Solvothermal)
# - Synthesis Procedure:
#   - Electrochemical Method:
#     - Two copper electrodes were used as anode and cathode.
#     - Dissolve 1.75 g H3BTC and 2.85 g TBAP in 240 mL ethanol/water (3:1) solution.
#     - Electrolysis was carried out in a self-contained electrochemical cell under constant voltages (15, 20, 25, and 30 V) for 3 hours.
#     - Products were washed three times with water and ethanol separately.
#     - Dried in an oven at 100 °C for 24 hours.
#   - Solvothermal Method:
#     - Dissolve 2.077 g Cu(NO3)2·3H2O in 15 mL deionized water.
#     - Dissolve 1.00 g H3BTC in 30 mL N,N-dimethylformamide/ethanol solution (1:1).
#     - Mix the two solutions and stir for 10 minutes.
#     - Transfer the mixture to a 70 mL Teflon-lined stainless-steel autoclave.
#     - Heat to 100 °C and hold for 12 hours.
#     - Cool to room temperature, filter, and wash three times with water and ethanol separately.
#     - Dried in an oven at 100 °C for 24 hours.
# - Additional Conditions: Not Provided
# - Justification:
#   - "Two copper electrodes were used as anode and cathode, respectively, for the synthesis of HKUST-1. The organic linker (1.75 g H3BTC) and supporting electrolyte (2.85 g TBAP) were dissolved in 240 mL ethanol/water (3:1) solution. Electrolysis was carried out in a self-contained electrochemical cell under constant voltages (15, 20, 25 and 30 V) that were held for 3 h, following which products blue in color were obtained. After that, the samples were washed three times with water and ethanol separately, and then dried in an oven at 100 °C for 24 h."
#   - "For comparison purposes, HKUST-1 was also prepared by the solvothermal method. Cu(NO3)2·3H2O (2.077 g) was dissolved in 15 mL deionized water. Separately, H3BTC (1.00 g) was dissolved in 30 mL N,N-dimethylformamide/ethanol solution (1:1). Then, the above two solutions were mixed and stirred for 10 min. After that, the mixture was transferred to a 70 mL Teflon-lined stainless-steel autoclave, then heated to 100 °C and held for 12 h. After cooling to room temperature, it was filtered and washed three times with water and ethanol separately, and then dried in an oven at 100 °C for 24 h."
#
# Parsed Result:
# Metal Precursor: Copper rod (purity = 99.9998%)
# Organic Linker: H3BTC (1,3,5-benzenetricarboxylic acid)
# Solvent: Ethanol/water (3:1)
# Temperature: Not Provided
# Reaction Type: Electrochemical, Solvothermal
# Reaction Time: 3 hours (Electrochemical), 12 hours (Solvothermal)
# Summarized Procedure: Electrochemical Method: Two copper electrodes were used as anode and cathode. Dissolve 1.75 g H3BTC and 2.85 g TBAP in 240 mL ethanol/water (3:1) solution. Electrolysis was carried out in a self-contained electrochemical cell under constant voltages (15, 20, 25, and 30 V) for 3 hours. Products were washed three times with water and ethanol separately. Dried in an oven at 100 °C for 24 hours. Solvothermal Method: Dissolve 2.077 g Cu(NO3)2·3H2O in 15 mL deionized water. Dissolve 1.00 g H3BTC in 30 mL N,N-dimethylformamide/ethanol solution (1:1). Mix the two solutions and stir for 10 minutes. Transfer the mixture to a 70 mL Teflon-lined stainless-steel autoclave. Heat to 100 °C and hold for 12 hours. Cool to room temperature, filter, and wash three times with water and ethanol separately. Dried in an oven at 100 °C for 24 hours.
# Additional Conditions: Not Provided
# Exact Sentences: "Two copper electrodes were used as anode and cathode, respectively, for the synthesis of HKUST-1. The organic linker (1.75 g H3BTC) and supporting electrolyte (2.85 g TBAP) were dissolved in 240 mL ethanol/water (3:1) solution. Electrolysis was carried out in a self-contained electrochemical cell under constant voltages (15, 20, 25 and 30 V) that were held for 3 h, following which products blue in color were obtained. After that, the samples were washed three times with water and ethanol separately, and then dried in an oven at 100 °C for 24 h." "For comparison purposes, HKUST-1 was also prepared by the solvothermal method. Cu(NO3)2·3H2O (2.077 g) was dissolved in 15 mL deionized water. Separately, H3BTC (1.00 g) was dissolved in 30 mL N,N-dimethylformamide/ethanol solution (1:1). Then, the above two solutions were mixed and stirred for 10 min. After that, the mixture was transferred to a 70 mL Teflon-lined stainless-steel autoclave, then heated to 100 °C and held for 12 h. After cooling to room temperature, it was filtered and washed three times with water and ethanol separately, and then dried in an oven at 100 °C for 24 h."
#
#
# Cross_Document_Linking/XML/10.1016_j.poly.2021.115517.xml
# Detected Elsevier XML format in 'Cross_Document_Linking/XML/10.1016_j.poly.2021.115517.xml'
# Converted 'Cross_Document_Linking/XML/10.1016_j.poly.2021.115517.xml' to Markdown at 'Cross_Document_Linking/MD/10.1016_j.poly.2021.115517.md'
# Action: reading the document
# finding all properties of name 1: HKUST-1
#
# Result:
# - Metal Precursor: Copper (II) nitrate trihydrate (Cu(NO3)2·3H2O)
# - Organic Linker: BTC (benzene-1,3,5-tricarboxylic acid)
# - Solvent: Distilled water, N, N'-dimethylformamide (DMF)
# - Temperature: 140 °C
# - Reaction Type: Solvothermal
# - Reaction Time: 5, 10, 15, and 30 min
# - Synthesis Procedure:
#   - Prepare a 0.34 M solution of copper (II) nitrate trihydrate in distilled water.
#   - Prepare a 0.17 M solution of benzene-1,3,5-tricarboxylic acid in N, N'-dimethylformamide (DMF).
#   - Mix 2.5 mL of each solution in a beaker at 500 rpm for 5 min.
#   - Transfer the homogenized solution to a borosilicate glass vial with a stirring bar and seal with a silicone cap.
#   - Place the reaction vessel in the Monowave 50 reactor.
#   - Heat at 140 °C and stir magnetically at 300 rpm for 5, 10, 15, and 30 min.
#   - Obtain blue dispersions and centrifuge at 3500 rpm for 10 min to get blue powders.
#   - Wash the powders three times with DMF and distilled water.
#   - Dry the powders in an oven at 120 °C for 3 h.
#   - Grind the dried powders in an agate mortar and store for characterization.
# - Additional Conditions: Magnetic stirring at 300 rpm, centrifugation at 3500 rpm for 10 min.
# - Justification: "HKUST-1 nanoparticles were synthesized by solvothermal method using a conductively heated sealed-vessel reactor model Monowave 50 (Anton Paar). First, a 0.34 M copper (II) nitrate trihydrate (Cu(NO3)2·3H2O) solution and a 0.17 M benzene-1,3,5-tricarboxylic acid (BTC) solution were prepared with distilled water and N, N'-dimethylformamide (DMF), respectively. Afterward, 2.5 mL of each solution was mixed in a beaker at 500 rpm for 5 min. Subsequently, this homogenized solution was transferred to a borosilicate glass vial along with a stirring bar and sealed with a silicone cap. Thereafter, the reaction vessel was put into the Monowave 50 reactor and heated at a temperature of 140 °C and magnetically stirred at 300 rpm for 5, 10, 15, and 30 min. Then, four blue dispersions were obtained and centrifugated at 3500 rpm for 10 min to obtain four blue powders. Next, these powders were washed three times with DMF and distilled water to eliminate unreacted precursors. Finally, the blue powders were dried in an oven at 120 °C for 3 h, ground in an agate mortar, and stored for their characterization."
#
# Parsed Result:
# Metal Precursor: Copper (II) nitrate trihydrate (Cu(NO3)2·3H2O)
# Organic Linker: BTC (benzene-1,3,5-tricarboxylic acid)
# Solvent: Distilled water, N, N'-dimethylformamide (DMF)
# Temperature: 140 °C
# Reaction Type: Solvothermal
# Reaction Time: 5, 10, 15, and 30 min
# Summarized Procedure: Prepare a 0.34 M solution of copper (II) nitrate trihydrate in distilled water. Prepare a 0.17 M solution of benzene-1,3,5-tricarboxylic acid in N, N'-dimethylformamide (DMF). Mix 2.5 mL of each solution in a beaker at 500 rpm for 5 min. Transfer the homogenized solution to a borosilicate glass vial with a stirring bar and seal with a silicone cap. Place the reaction vessel in the Monowave 50 reactor. Heat at 140 °C and stir magnetically at 300 rpm for 5, 10, 15, and 30 min. Obtain blue dispersions and centrifuge at 3500 rpm for 10 min to get blue powders. Wash the powders three times with DMF and distilled water. Dry the powders in an oven at 120 °C for 3 h. Grind the dried powders in an agate mortar and store for characterization.
# Additional Conditions: Magnetic stirring at 300 rpm, centrifugation at 3500 rpm for 10 min.
# Exact Sentences: HKUST-1 nanoparticles were synthesized by solvothermal method using a conductively heated sealed-vessel reactor model Monowave 50 (Anton Paar). First, a 0.34 M copper (II) nitrate trihydrate (Cu(NO3)2·3H2O) solution and a 0.17 M benzene-1,3,5-tricarboxylic acid (BTC) solution were prepared with distilled water and N, N'-dimethylformamide (DMF), respectively. Afterward, 2.5 mL of each solution was mixed in a beaker at 500 rpm for 5 min. Subsequently, this homogenized solution was transferred to a borosilicate glass vial along with a stirring bar and sealed with a silicone cap. Thereafter, the reaction vessel was put into the Monowave 50 reactor and heated at a temperature of 140 °C and magnetically stirred at 300 rpm for 5, 10, 15, and 30 min. Then, four blue dispersions were obtained and centrifugated at 3500 rpm for 10 min to obtain four blue powders. Next, these powders were washed three times with DMF and distilled water to eliminate unreacted precursors. Finally, the blue powders were dried in an oven at 120 °C for 3 h, ground in an agate mortar, and stored for their characterization.
#
#
# Cross_Document_Linking/XML/10.1016_j.ijbiomac.2023.124627.xml
# Detected Elsevier XML format in 'Cross_Document_Linking/XML/10.1016_j.ijbiomac.2023.124627.xml'
# Converted 'Cross_Document_Linking/XML/10.1016_j.ijbiomac.2023.124627.xml' to Markdown at 'Cross_Document_Linking/MD/10.1016_j.ijbiomac.2023.124627.md'
# Action: reading the document
# finding all properties of name 1: HKUST-1
#
# Result:
# - Metal Precursor: Copper (II) nitrate trihydrate (Cu(NO3)2·3H2O)
# - Organic Linker: H3BTC (1,3,5-benzenetricarboxylic acid)
# - Solvent: Water
# - Temperature: Room temperature
# - Reaction Type: Not explicitly mentioned, but the process involves sonication and stirring.
# - Reaction Time: 1 hour
# - Synthesis Procedure:
#   - Prepare a solution of 0.4 mmol Cu(NO3)2·6H2O in 5 ml water.
#   - Add a suspension of 0.8 mmol of H3BTC in 10 ml of water to the solution.
#   - Disperse the mixture in an ultrasonic bath for 10 minutes.
#   - Stir the mixture for 1 hour at room temperature on a stir plate.
#   - Collect the blue precipitates by centrifugation.
#   - Wash the precipitates three times with a mixture of water and ethanol to remove any unreacted chemicals.
#   - Dry the blue products overnight at 80 °C in a vacuum oven.
# - Additional Conditions: None mentioned.
# - Justification: "A beaker was filled with a freshly prepared solution of 0.4 mmol Cu (NO3)2·6H2O in 5 ml water. Then, a suspension of 0.8 mmol of (H3BTC) in 10 ml of water was added to the beaker. The mixture was dispersed in an ultrasonic bath for 10 min and stirred for 1 h at room temperature on a stir plate. Once the reaction was completed, the blue precipitates were collected by centrifugation and washed three times with a mixture of water and ethanol to remove any unreacted chemicals. The blue products were then obtained by drying overnight at 80 °C in a vacuum oven."
#
# Parsed Result:
# Metal Precursor: Copper (II) nitrate trihydrate (Cu(NO3)2·3H2O)
# Organic Linker: H3BTC (1,3,5-benzenetricarboxylic acid)
# Solvent: Water
# Temperature: Room temperature
# Reaction Type: Sonication and stirring
# Reaction Time: 1 hour
# Summarized Procedure: Prepare a solution of 0.4 mmol Cu(NO3)2·6H2O in 5 ml water. Add a suspension of 0.8 mmol of H3BTC in 10 ml of water to the solution. Disperse the mixture in an ultrasonic bath for 10 minutes. Stir the mixture for 1 hour at room temperature on a stir plate. Collect the blue precipitates by centrifugation. Wash the precipitates three times with a mixture of water and ethanol to remove any unreacted chemicals. Dry the blue products overnight at 80 °C in a vacuum oven.
# Additional Conditions: None mentioned.
# Exact Sentences: A beaker was filled with a freshly prepared solution of 0.4 mmol Cu (NO3)2·6H2O in 5 ml water. Then, a suspension of 0.8 mmol of (H3BTC) in 10 ml of water was added to the beaker. The mixture was dispersed in an ultrasonic bath for 10 min and stirred for 1 h at room temperature on a stir plate. Once the reaction was completed, the blue precipitates were collected by centrifugation and washed three times with a mixture of water and ethanol to remove any unreacted chemicals. The blue products were then obtained by drying overnight at 80 °C in a vacuum oven.
#
#
# Cross_Document_Linking/XML/10.1016_j.jwpe.2020.101670.xml
# Detected Elsevier XML format in 'Cross_Document_Linking/XML/10.1016_j.jwpe.2020.101670.xml'
# Converted 'Cross_Document_Linking/XML/10.1016_j.jwpe.2020.101670.xml' to Markdown at 'Cross_Document_Linking/MD/10.1016_j.jwpe.2020.101670.md'
# Action: reading the document
# finding all properties of name 1: HKUST-1
#
# Result:
# - Metal Precursor: Copper(II) nitrate trihydrate (Cu(NO3)2.3H2O)
# - Organic Linker: H3BTC (benzene-1,3,5-tricarboxylic acid)
# - Solvent: Water, ethanol, N,N-Dimethylformamide (DMF) in a 1:1:1 volume ratio
# - Temperature: 100 °C
# - Reaction Type: Solvothermal
# - Reaction Time: 10 hours
# - Synthesis Procedure:
#   - Dissolve 1 g of H3BTC in 30 mL of a solvent mixture with a 1:1 ratio of ethanol:DMF.
#   - In a separate container, dissolve 2.077 g of Cu(NO3)2.3H2O in 15 mL of distilled water.
#   - Mix the two solutions in a vial bottle and stir using a magnetic stirrer for 15 minutes.
#   - Place the reaction mixture in an oven at 100 °C for 10 hours.
#   - Leave the mixture at room temperature for two days, followed by filtration.
#   - Measure the volume of mother liquor, denoted as F1, and reuse it for subsequent synthesis.
#   - Wash the precipitate with 20 mL of DMF, then with 20 mL of chloroform.
#   - Immerse the precipitate three times in 30 mL of warm methanol at temperatures between 40—55 °C for 24 hours each time.
#   - Separate and dry the light blue precipitate in an oven at 70 °C.
# - Additional Conditions: The addition of CTABr was carried out after the H3BTC ligand completely dissolved.
# - Justification: "The method used for the synthesis of HKUST-1 in this study was the solvothermal method, as reported by Chui et al. [7] and modified by Ediati et al. [10]. Typically, 1 g of H3BTC was dissolved in 30 mL of solvent mixture with a 1 : 1 ratio of ethanol : DMF. Then in a separate container, as much as 2.077 g of Cu(NO3)2.3H2O was dissolved in 15 mL of distilled water. The addition of CTABr was carried out after the H3BTC ligand completely dissolved. The two solutions were mixed in a vial bottle and stirred using a magnetic stirrer for 15 min. The reaction mixture was placed in an oven at a temperature of 100 °C for 10 h and then left at room temperature for two days, followed by filtration. The volume of mother liquor was measured, denoted as F1, and reused for the subsequent synthesis of HKUST-1. The precipitate formed was washed with 20 mL of DMF, then washed in 20 mL of chloroform, then immersed three times in 30 mL of warm methanol at temperatures between 40—55 °C 24 h each time. The light blue precipitate was then separated, dried in an oven at a temperature of 70 °C, and denoted as HKUST-1(S1)."
#
# Parsed Result:
# Metal Precursor: Copper(II) nitrate trihydrate (Cu(NO3)2.3H2O)
# Organic Linker: H3BTC (benzene-1,3,5-tricarboxylic acid)
# Solvent: Water, ethanol, N,N-Dimethylformamide (DMF) in a 1:1:1 volume ratio
# Temperature: 100 °C
# Reaction Type: Solvothermal
# Reaction Time: 10 hours
# Summarized Procedure: Dissolve 1 g of H3BTC in 30 mL of a solvent mixture with a 1:1 ratio of ethanol:DMF. In a separate container, dissolve 2.077 g of Cu(NO3)2.3H2O in 15 mL of distilled water. Mix the two solutions in a vial bottle and stir using a magnetic stirrer for 15 minutes. Place the reaction mixture in an oven at 100 °C for 10 hours. Leave the mixture at room temperature for two days, followed by filtration. Measure the volume of mother liquor, denoted as F1, and reuse it for subsequent synthesis. Wash the precipitate with 20 mL of DMF, then with 20 mL of chloroform. Immerse the precipitate three times in 30 mL of warm methanol at temperatures between 40—55 °C for 24 hours each time. Separate and dry the light blue precipitate in an oven at 70 °C.
# Additional Conditions: The addition of CTABr was carried out after the H3BTC ligand completely dissolved.
# Exact Sentences: "The method used for the synthesis of HKUST-1 in this study was the solvothermal method, as reported by Chui et al. [7] and modified by Ediati et al. [10]. Typically, 1 g of H3BTC was dissolved in 30 mL of solvent mixture with a 1 : 1 ratio of ethanol : DMF. Then in a separate container, as much as 2.077 g of Cu(NO3)2.3H2O was dissolved in 15 mL of distilled water. The addition of CTABr was carried out after the H3BTC ligand completely dissolved. The two solutions were mixed in a vial bottle and stirred using a magnetic stirrer for 15 min. The reaction mixture was placed in an oven at a temperature of 100 °C for 10 h and then left at room temperature for two days, followed by filtration. The volume of mother liquor was measured, denoted as F1, and reused for the subsequent synthesis of HKUST-1. The precipitate formed was washed with 20 mL of DMF, then washed in 20 mL of chloroform, then immersed three times in 30 mL of warm methanol at temperatures between 40—55 °C 24 h each time. The light blue precipitate was then separated, dried in an oven at a temperature of 70 °C, and denoted as HKUST-1(S1)."
#
#
# Cross_Document_Linking/XML/10.1016_j.apt.2022.103701.xml
# Detected Elsevier XML format in 'Cross_Document_Linking/XML/10.1016_j.apt.2022.103701.xml'
# Converted 'Cross_Document_Linking/XML/10.1016_j.apt.2022.103701.xml' to Markdown at 'Cross_Document_Linking/MD/10.1016_j.apt.2022.103701.md'
# Action: reading the document
# finding all properties of name 1: HKUST-1
#
# Result:
# - Metal Precursor: Copper nitrate trihydrate (Cu(NO3)2·3H2O)
# - Organic Linker: H3BTC (1,3,5-benzenetricarboxylic acid)
# - Solvent: Water, ethanol, N,N-dimethylformamide (DMF)
# - Temperature: 200 °C (spray synthesis), 80 °C (batch synthesis)
# - Reaction Type: Spray synthesis, batch synthesis
# - Reaction Time: Less than one second (spray synthesis), 12 hours (batch synthesis)
# - Synthesis Procedure:
#   - **Spray Synthesis:**
#     - Prepare a CuNO3 solution by dissolving 0.871 g of Cu(NO3)2·6H2O in 7 mL of water.
#     - Prepare a H3BTC solution by dissolving 0.506 g of H3BTC in a co-solvent containing 7 mL each of ethanol and DMF with stirring.
#     - Obtain the HKUST-1 mother solution by mixing the two aforementioned solutions.
#     - Use a homemade spraying apparatus with a two-fluid nozzle to spray the mother solution.
#     - Feed the solution into the nozzle using a syringe pump at a flow rate of 3 mL/min and spray with clean air at a flow rate of 12 L/min.
#     - Supply swirling air at a flow rate of 30 L/min and temperature of 180 °C.
#     - Heat the sprayed droplets through a heating tube at 200 °C.
#     - Collect the samples using a glass filter, wash with water and ethanol, ultrasonicate, and centrifuge to eliminate residual precursors.
#     - Dry the samples at 80 °C for 6 hours.
#   - **Batch Synthesis:**
#     - Heat the HKUST-1 mother solution at 80 °C for 12 hours.
#     - After crystallization, filter and wash the samples three times with ethanol.
#     - Dry the samples at 60 °C for one day.
# - Additional Conditions: Not Provided
# - Justification:
#   - "We recently developed a spray synthesis method to synthesize HKUST-1 [Cu3(BTC)2; H3BTC = 1, 3, 5-benzenetricarboxylic acid] in less than one second by MOF precursor solution spraying and subsequent heating."
#   - "A CuNO3 solution was prepared by dissolving 0.871 g of Cu(NO3)2·6H2O in 7 mL of water. A H3BTC solution was prepared by dissolving 0.506 g of H3BTC in a co-solvent containing 7 mL each of ethanol and DMF with stirring."
#   - "The mother solution was fed into the two-fluid nozzle using a syringe pump at a flow rate of 3 mL/min and sprayed simultaneously with clean air at a flow rate of 12 L/min."
#   - "The sprayed droplets were heated through a heating tube at 200 °C."
#   - "Batch synthesis was performed to compare the amounts of Pd NPs incorporated in HKUST-1. The Pd/HKUST-1 mother solution was heated at 80 °C for 12 h."
#
# Parsed Result:
# Metal Precursor: Copper nitrate trihydrate (Cu(NO3)2·3H2O)
# Organic Linker: H3BTC (1,3,5-benzenetricarboxylic acid)
# Solvent: Water, ethanol, N,N-dimethylformamide (DMF)
# Temperature: 200 °C (spray synthesis), 80 °C (batch synthesis)
# Reaction Type: Spray synthesis, batch synthesis
# Reaction Time: Less than one second (spray synthesis), 12 hours (batch synthesis)
# Summarized Procedure: Spray Synthesis: Prepare a CuNO3 solution by dissolving 0.871 g of Cu(NO3)2·6H2O in 7 mL of water. Prepare a H3BTC solution by dissolving 0.506 g of H3BTC in a co-solvent containing 7 mL each of ethanol and DMF with stirring. Obtain the HKUST-1 mother solution by mixing the two aforementioned solutions. Use a homemade spraying apparatus with a two-fluid nozzle to spray the mother solution. Feed the solution into the nozzle using a syringe pump at a flow rate of 3 mL/min and spray with clean air at a flow rate of 12 L/min. Supply swirling air at a flow rate of 30 L/min and temperature of 180 °C. Heat the sprayed droplets through a heating tube at 200 °C. Collect the samples using a glass filter, wash with water and ethanol, ultrasonicate, and centrifuge to eliminate residual precursors. Dry the samples at 80 °C for 6 hours. Batch Synthesis: Heat the HKUST-1 mother solution at 80 °C for 12 hours. After crystallization, filter and wash the samples three times with ethanol. Dry the samples at 60 °C for one day.
# Additional Conditions: Not Provided
# Exact Sentences: "We recently developed a spray synthesis method to synthesize HKUST-1 [Cu3(BTC)2; H3BTC = 1, 3, 5-benzenetricarboxylic acid] in less than one second by MOF precursor solution spraying and subsequent heating." "A CuNO3 solution was prepared by dissolving 0.871 g of Cu(NO3)2·6H2O in 7 mL of water. A H3BTC solution was prepared by dissolving 0.506 g of H3BTC in a co-solvent containing 7 mL each of ethanol and DMF with stirring." "The mother solution was fed into the two-fluid nozzle using a syringe pump at a flow rate of 3 mL/min and sprayed simultaneously with clean air at a flow rate of 12 L/min." "The sprayed droplets were heated through a heating tube at 200 °C." "Batch synthesis was performed to compare the amounts of Pd NPs incorporated in HKUST-1. The Pd/HKUST-1 mother solution was heated at 80 °C for 12 h."
#
#
# Cross_Document_Linking/XML/10.1016_j.cej.2020.127396.xml
# Detected Elsevier XML format in 'Cross_Document_Linking/XML/10.1016_j.cej.2020.127396.xml'
# Converted 'Cross_Document_Linking/XML/10.1016_j.cej.2020.127396.xml' to Markdown at 'Cross_Document_Linking/MD/10.1016_j.cej.2020.127396.md'
# Action: reading the document
# finding all properties of name 1: HKUST-1
#
# Result:
# - Metal Precursor: Copper nitrate trihydrate (Cu(NO3)2·3H2O)
# - Organic Linker: H3BTC (benzene-1,3,5-tricarboxylic acid)
# - Solvent: Deionized water, ethanol (1:1 ratio)
# - Temperature: 393 K
# - Reaction Type: Solvothermal
# - Reaction Time: 12 hours
# - Synthesis Procedure:
#   - Dissolve 1.050 g of H3BTC and 2.174 g of Cu(NO3)2·3H2O in 30 mL of deionized water mixed with 30 mL of ethanol.
#   - Stir the mixture for 30 minutes.
#   - Transfer the mixture into a Teflon-lined stainless autoclave.
#   - Heat the autoclave at 393 K for 12 hours.
#   - After cooling to room temperature, centrifuge the product.
#   - Wash the product with deionized water and ethanol alternately several times.
#   - Dry the obtained blue crystals at 423 K in a vacuum oven overnight to yield HKUST-1.
# - Additional Conditions: Not Provided
# - Justification: "The pristine HKUST-1 was synthesized through a solvothermal method starting from copper nitrate trihydrate and benzene-1,3,5-tricarboxylic acid [35]. In general, 1.050 g of H3BTC and 2.174 g of Cu(NO3)2·3H2O were dissolved into 30 mL of deionized water mixed with 30 mL of ethanol. After stirring for 30 min, the mixture was transferred into a Teflon-lined stainless autoclave and heated at 393 K for 12 h. After cooling down to room temperature, the product was centrifuged and washed with deionized water and ethanol alternately for several times. Finally, the obtained blue crystals were dried at 423 K in the vacuum oven overnight to yield HKUST-1."
#
# Parsed Result:
# Metal Precursor: Copper nitrate trihydrate (Cu(NO3)2·3H2O)
# Organic Linker: H3BTC (benzene-1,3,5-tricarboxylic acid)
# Solvent: Deionized water, ethanol (1:1 ratio)
# Temperature: 393 K
# Reaction Type: Solvothermal
# Reaction Time: 12 hours
# Summarized Procedure: Dissolve 1.050 g of H3BTC and 2.174 g of Cu(NO3)2·3H2O in 30 mL of deionized water mixed with 30 mL of ethanol. Stir the mixture for 30 minutes. Transfer the mixture into a Teflon-lined stainless autoclave. Heat the autoclave at 393 K for 12 hours. After cooling to room temperature, centrifuge the product. Wash the product with deionized water and ethanol alternately several times. Dry the obtained blue crystals at 423 K in a vacuum oven overnight to yield HKUST-1.
# Additional Conditions: Not Provided
# Exact Sentences: The pristine HKUST-1 was synthesized through a solvothermal method starting from copper nitrate trihydrate and benzene-1,3,5-tricarboxylic acid [35]. In general, 1.050 g of H3BTC and 2.174 g of Cu(NO3)2·3H2O were dissolved into 30 mL of deionized water mixed with 30 mL of ethanol. After stirring for 30 min, the mixture was transferred into a Teflon-lined stainless autoclave and heated at 393 K for 12 h. After cooling down to room temperature, the product was centrifuged and washed with deionized water and ethanol alternately for several times. Finally, the obtained blue crystals were dried at 423 K in the vacuum oven overnight to yield HKUST-1.
#
#
# Cross_Document_Linking/XML/10.1016_j.inoche.2020.107975.xml
# Detected Elsevier XML format in 'Cross_Document_Linking/XML/10.1016_j.inoche.2020.107975.xml'
# Converted 'Cross_Document_Linking/XML/10.1016_j.inoche.2020.107975.xml' to Markdown at 'Cross_Document_Linking/MD/10.1016_j.inoche.2020.107975.md'
# Action: reading the document
# finding all properties of name 1: HKUST-1
#
# Result:
# - Metal Precursor: Copper (II) nitrate trihydrate
# - Organic Linker: H3BTC (1,3,5-benzenetricarboxylic acid)
# - Solvent: Ethanol—water solution (1:1, volume ratio)
# - Temperature: Room temperature
# - Reaction Type: In-situ growth method
# - Reaction Time: 5 hours
# - Synthesis Procedure:
#   - Suspend SiO2 ceramic in 30 mL ethanol—water solution (1:1, volume ratio) and treat for 2 hours to sufficiently wet the SiO2 ceramic.
# ...
#   - Disperse and dissolve 2.5 g of H3BTC in 75 mL anhydrous ethanol and sonicate for 10 minutes.
#   - Mix the two solutions and stir for 30 minutes.
#   - Add 3 g of Fe3O4@PDA and stir for 1 hour to ensure thorough mixing.
#   - Transfer the solution to an autoclave and place it in an oven at 150 °C for 15 hours.
#   - After the reaction, cool the reactor to room temperature with the oven.
#   - Remove the reactor, perform magnetic separation using a strong magnet, wash three times with water and anhydrous ethanol, and dry overnight at 60 °C in a vacuum drying oven.
# - Additional Conditions: Not Provided
# - Justification: "First, 5 g of Cu(NO3)2·3H2O was dispersed and dissolved in 75 mL deionized water and sonicated for 10 min (power 500 W); 2.5 g of H3BTC was dispersed and dissolved in 75 mL anhydrous ethanol and sonicated for 10 min. The above two solutions were mixed and stirred for 30 min. Then, 3 g Fe3O4@PDA was added and stirred for 1 h to make it well mixed. The solution was transferred to an autoclave, and then the autoclave was placed in an oven at 150 °C for 15 h. After the reaction, the reactor was cooled to room temperature with the oven. The reactor was removed, magnetically separated using a strong magnet, washed three times with water and anhydrous ethanol, dried overnight at 60 °C in a vacuum drying oven, and collected the product."
#
# Parsed Result:
# Metal Precursor: Copper nitrate trihydrate (Cu(NO3)2·3H2O)
# Organic Linker: H3BTC (1,3,5-benzenetricarboxylic acid)
# Solvent: Deionized water, anhydrous ethanol
# Temperature: 150 °C
# Reaction Type: Solvothermal
# Reaction Time: 15 hours
# Summarized Procedure: Disperse and dissolve 5 g of Cu(NO3)2·3H2O in 75 mL deionized water and sonicate for 10 minutes. Disperse and dissolve 2.5 g of H3BTC in 75 mL anhydrous ethanol and sonicate for 10 minutes. Mix the two solutions and stir for 30 minutes. Add 3 g of Fe3O4@PDA and stir for 1 hour to ensure thorough mixing. Transfer the solution to an autoclave and place it in an oven at 150 °C for 15 hours. After the reaction, cool the reactor to room temperature with the oven. Remove the reactor, perform magnetic separation using a strong magnet, wash three times with water and anhydrous ethanol, and dry overnight at 60 °C in a vacuum drying oven.
# Additional Conditions: Not Provided
# Exact Sentences: First, 5 g of Cu(NO3)2·3H2O was dispersed and dissolved in 75 mL deionized water and sonicated for 10 min (power 500 W); 2.5 g of H3BTC was dispersed and dissolved in 75 mL anhydrous ethanol and sonicated for 10 min. The above two solutions were mixed and stirred for 30 min. Then, 3 g Fe3O4@PDA was added and stirred for 1 h to make it well mixed. The solution was transferred to an autoclave, and then the autoclave was placed in an oven at 150 °C for 15 h. After the reaction, the reactor was cooled to room temperature with the oven. The reactor was removed, magnetically separated using a strong magnet, washed three times with water and anhydrous ethanol, dried overnight at 60 °C in a vacuum drying oven, and collected the product.
#
#
# Cross_Document_Linking/XML/10.1016_j.hazl.2023.100094.xml
# Detected Elsevier XML format in 'Cross_Document_Linking/XML/10.1016_j.hazl.2023.100094.xml'
# Converted 'Cross_Document_Linking/XML/10.1016_j.hazl.2023.100094.xml' to Markdown at 'Cross_Document_Linking/MD/10.1016_j.hazl.2023.100094.md'
# Action: reading the document
# finding all properties of name 1: HKUST-1
#
# Result:
# - Metal Precursor: Cu(NO3)2·3H2O, Cu(NO3)2·6H2O
# - Organic Linker: H3BTC (1,3,5-benzenetricarboxylic acid)
# - Solvent: Water, Ethanol
# - Temperature: 80 °C, 120 °C, 393 K
# - Reaction Type: Solvothermal, Hydrothermal, Microwave-assisted
# - Reaction Time: 3 h, 12 h, 30 min
# - Synthesis Procedure:
#   - **Solvothermal Approach**:
#     - Continuously stir H3BTC in a mixture of metal ions and solvent for 3 hours at a constant temperature of 80 °C.
#     - Filter the reaction mixture and evaporate the solvent to produce pure crystals of MOF.
#   - **Hydrothermal Synthesis**:
#     - Mix an aqueous solution of Cu(NO3)2·3H2O with an ethanolic solution of H3BTC for 30 minutes.
#     - Heat the mixture inside a Teflon-coated autoclave at 120 °C for 12 hours.
#     - Cool the reactor, purify the resulting light blue product with ethanol, and vacuum dry at 80 °C overnight.
#   - **Microwave-assisted Synthesis**:
#     - Introduce an aqueous solution of Cu(NO3)2·6H2O into an ethanolic solution of H3BTC and stir for 2 hours.
#     - Transfer the mixture to a reactor and place it in a microwave synthesizer.
#     - Conduct the reaction by heating to 393 K for 20 minutes, followed by cooling to room temperature.
#     - Centrifuge and dry the product overnight at 393 K.
# - Additional Conditions: Not Provided
# - Justification:
#   - "The most extensively utilized technique for the liquid phase synthesis of Cu-BTC MOF is the solvothermal approach. This entails continuous stirring of H3BTC in a mixture of metal ions and solvent for 3 h maintained at a constant temperature of 80 °C."
#   - "Hydrothermal synthesis, is considered as one of the environment-friendly method for the synthesis of Cu-BTC, that utilizes water instead of potentially hazardous organic solvents. This technique involves mixing of an aqueous solution of Cu(NO3)2·3H2O to an ethanolic solution of H3BTC for 30 min before being heated inside a Teflon coated autoclave at 120 ºC for 12 h."
#   - "The microwave-assisted synthesis offers a significantly accelerated approach for the synthesis of Cu-BTC compared to the hydrothermal approach, reducing the synthesis time from 24 h to just 30 min. In a typical synthesis, an aqueous solution of Cu(NO3)2·6H2O is introduced into an ethanolic solution of H3BTC, stirred for 2 h before being transferred to a reactor, and placed in a microwave synthesizer. The reaction is conducted by heating it to 393 K for 20 min, followed by cooling to room temperature, and subsequently centrifugated and dried overnight at 393 K."
#
# Parsed Result:
# Metal Precursor: Cu(NO3)2·3H2O, Cu(NO3)2·6H2O
# Organic Linker: H3BTC (1,3,5-benzenetricarboxylic acid)
# Solvent: Water, Ethanol
# Temperature: 80 °C, 120 °C, 393 K
# Reaction Type: Solvothermal, Hydrothermal, Microwave-assisted
# Reaction Time: 3 h, 12 h, 30 min
# Summarized Procedure: Solvothermal Approach: Continuously stir H3BTC in a mixture of metal ions and solvent for 3 hours at a constant temperature of 80 °C. Filter the reaction mixture and evaporate the solvent to produce pure crystals of MOF. Hydrothermal Synthesis: Mix an aqueous solution of Cu(NO3)2·3H2O with an ethanolic solution of H3BTC for 30 minutes. Heat the mixture inside a Teflon-coated autoclave at 120 °C for 12 hours. Cool the reactor, purify the resulting light blue product with ethanol, and vacuum dry at 80 °C overnight. Microwave-assisted Synthesis: Introduce an aqueous solution of Cu(NO3)2·6H2O into an ethanolic solution of H3BTC and stir for 2 hours. Transfer the mixture to a reactor and place it in a microwave synthesizer. Conduct the reaction by heating to 393 K for 20 minutes, followed by cooling to room temperature. Centrifuge and dry the product overnight at 393 K.
# Additional Conditions: Not Provided
# Exact Sentences: The most extensively utilized technique for the liquid phase synthesis of Cu-BTC MOF is the solvothermal approach. This entails continuous stirring of H3BTC in a mixture of metal ions and solvent for 3 h maintained at a constant temperature of 80 °C. Hydrothermal synthesis, is considered as one of the environment-friendly method for the synthesis of Cu-BTC, that utilizes water instead of potentially hazardous organic solvents. This technique involves mixing of an aqueous solution of Cu(NO3)2·3H2O to an ethanolic solution of H3BTC for 30 min before being heated inside a Teflon coated autoclave at 120 ºC for 12 h. The microwave-assisted synthesis offers a significantly accelerated approach for the synthesis of Cu-BTC compared to the hydrothermal approach, reducing the synthesis time from 24 h to just 30 min. In a typical synthesis, an aqueous solution of Cu(NO3)2·6H2O is introduced into an ethanolic solution of H3BTC, stirred for 2 h before being transferred to a reactor, and placed in a microwave synthesizer. The reaction is conducted by heating it to 393 K for 20 min, followed by cooling to room temperature, and subsequently centrifugated and dried overnight at 393 K.
#
#
# Cross_Document_Linking/XML/10.1016_j.apsb.2024.03.014.xml
# Detected Elsevier XML format in 'Cross_Document_Linking/XML/10.1016_j.apsb.2024.03.014.xml'
# Converted 'Cross_Document_Linking/XML/10.1016_j.apsb.2024.03.014.xml' to Markdown at 'Cross_Document_Linking/MD/10.1016_j.apsb.2024.03.014.md'
# Action: reading the document
# finding all properties of name 1: HKUST-1
#
# Result:
# - Metal Precursor: Cu(CH3COO)2·H2O (Copper(II) acetate monohydrate)
# - Organic Linker: H3BTC (trimesic acid, [1,3,5-benzenetricarboxylic acid])
# - Solvent: 25% aqueous solution of dimethylformamide (DMF), 25% (v/v) solution of DMF in ethanol
# - Temperature: Not Provided
# - Reaction Type: Not Provided
# - Reaction Time: 3 hours stirring, 30 minutes sonication
# - Synthesis Procedure:
#   - Prepare a solution of 1.2 g Cu(CH3COO)2·H2O and 2.4 g of polyvinylpyrrolidone (PVP) in 60 mL of a 25% aqueous solution of DMF to obtain the Cu(CH3COO)2 solution.
#   - Prepare a solution of 0.42 g H3BTC in 40 mL of a 25% (v/v) solution of DMF in ethanol to obtain the H3BTC solution.
#   - Add the Cu(CH3COO)2 solution dropwise to the H3BTC solution with stirring.
#   - Add 1 mL of TEA (triethylamine) to the reaction mixture.
#   - Stir the reaction mixture for 3 hours and sonicate for 30 minutes to obtain the HKUST-1 suspension.
#   - Wash the sample with ultrapure water, DMF, DCM (dichloromethane), and EtOH (ethanol) three times.
#   - Disperse the sample in EtOH and remove the EtOH by rotary evaporation to obtain HKUST-1 nanoparticles.
# - Additional Conditions: Not Provided
# - Justification: "HKUST-1 nanoparticles were prepared with slight modification based on a previously reported method50. In brief, a solution of 1.2 g Cu(CH3COO)2·H2O (6 mmol) and 2.4 g of polyvinylpyrrolidone (PVP) in 60 mL of a 25% aqueous solution of dimethylformamide (DMF) was prepared to obtain the Cu(CH3COO)2 solution. A solution of 0.42 g H3BTC (trimesic acid, two mmol) in 40 mL of a 25% (v/v) solution of DMF in ethanol was prepared to obtain the H3BTC solution. The Cu(CH3COO)2 solution was added dropwise to the H3BTC solution with stirring, and 1 mL of TEA (triethylamine) was added to the reaction mixture. The reaction mixture was stirred for 3 h and sonicated for 30 min to obtain the HKUST-1 suspension. The sample was then washed with ultrapure water, DMF, DCM (dichloromethane), and EtOH (ethanol) three times. Finally, the sample was dispersed in EtOH, and the EtOH was removed by rotary evaporation to obtain HKUST-1 nanoparticles."
#
# Parsed Result:
# Metal Precursor: Cu(CH3COO)2·H2O (Copper(II) acetate monohydrate)
# Organic Linker: H3BTC (trimesic acid, [1,3,5-benzenetricarboxylic acid])
# Solvent: 25% aqueous solution of dimethylformamide (DMF), 25% (v/v) solution of DMF in ethanol
# Temperature: Not Provided
# Reaction Type: Not Provided
# Reaction Time: 3 hours stirring, 30 minutes sonication
# Summarized Procedure: Prepare a solution of 1.2 g Cu(CH3COO)2·H2O and 2.4 g of polyvinylpyrrolidone (PVP) in 60 mL of a 25% aqueous solution of DMF to obtain the Cu(CH3COO)2 solution. Prepare a solution of 0.42 g H3BTC in 40 mL of a 25% (v/v) solution of DMF in ethanol to obtain the H3BTC solution. Add the Cu(CH3COO)2 solution dropwise to the H3BTC solution with stirring. Add 1 mL of TEA (triethylamine) to the reaction mixture. Stir the reaction mixture for 3 hours and sonicate for 30 minutes to obtain the HKUST-1 suspension. Wash the sample with ultrapure water, DMF, DCM (dichloromethane), and EtOH (ethanol) three times. Disperse the sample in EtOH and remove the EtOH by rotary evaporation to obtain HKUST-1 nanoparticles.
# Additional Conditions: Not Provided
# Exact Sentences: HKUST-1 nanoparticles were prepared with slight modification based on a previously reported method50. In brief, a solution of 1.2 g Cu(CH3COO)2·H2O (6 mmol) and 2.4 g of polyvinylpyrrolidone (PVP) in 60 mL of a 25% aqueous solution of dimethylformamide (DMF) was prepared to obtain the Cu(CH3COO)2 solution. A solution of 0.42 g H3BTC (trimesic acid, two mmol) in 40 mL of a 25% (v/v) solution of DMF in ethanol was prepared to obtain the H3BTC solution. The Cu(CH3COO)2 solution was added dropwise to the H3BTC solution with stirring, and 1 mL of TEA (triethylamine) was added to the reaction mixture. The reaction mixture was stirred for 3 h and sonicated for 30 min to obtain the HKUST-1 suspension. The sample was then washed with ultrapure water, DMF, DCM (dichloromethane), and EtOH (ethanol) three times. Finally, the sample was dispersed in EtOH, and the EtOH was removed by rotary evaporation to obtain HKUST-1 nanoparticles.
#
#
# Cross_Document_Linking/XML/10.1016_j.memsci.2020.118412.xml
# Detected Elsevier XML format in 'Cross_Document_Linking/XML/10.1016_j.memsci.2020.118412.xml'
# Converted 'Cross_Document_Linking/XML/10.1016_j.memsci.2020.118412.xml' to Markdown at 'Cross_Document_Linking/MD/10.1016_j.memsci.2020.118412.md'
# Action: reading the document
# finding all properties of name 1: HKUST-1
#
# Result:
# - Metal Precursor: Cu(CH3COO)2·H2O
# - Organic Linker: 1,3,5-benzene tricarboxylic acid (BTC)
# - Solvent: Not Provided
# - Temperature: Not Provided
# - Reaction Type: Not Provided
# - Reaction Time: Not Provided
# - Synthesis Procedure: Not Provided
# - Additional Conditions: Not Provided
# - Justification: "Zn(NO3)2·6H2O, Co(NO3)2·6H2O, Cu(CH3COO)2·H2O, ethanol, methanol, toluene, cyclohexane, hexane, Methylene blue, Methylene blue and sodium chloride (NaCl) were obtained from Sinopharm Chemical Reagent Co., Ltd. Acetonitrile P-phenylenediamine (PPD, >99.0%), sodium nitrite (NaNO2) and reducing zinc power were obtained from Sigma Aldrich. Acid fuschin and Rose Bengal were purchased from Aladdin."
#
# Parsed Result:
# Metal Precursor: Cu(CH3COO)2·H2O
# Organic Linker: 1,3,5-benzene tricarboxylic acid (BTC)
# Solvent: Not Provided
# Temperature: Not Provided
# Reaction Type: Not Provided
# Reaction Time: Not Provided
# Summarized Procedure: Not Provided
# Additional Conditions: Not Provided
# Exact Sentences: Zn(NO3)2·6H2O, Co(NO3)2·6H2O, Cu(CH3COO)2·H2O, ethanol, methanol, toluene, cyclohexane, hexane, Methylene blue, Methylene blue and sodium chloride (NaCl) were obtained from Sinopharm Chemical Reagent Co., Ltd. Acetonitrile P-phenylenediamine (PPD, >99.0%), sodium nitrite (NaNO2) and reducing zinc power were obtained from Sigma Aldrich. Acid fuschin and Rose Bengal were purchased from Aladdin.
#
#
# Cross_Document_Linking/XML/10.1016_j.chemosphere.2016.02.005.xml
# Detected Elsevier XML format in 'Cross_Document_Linking/XML/10.1016_j.chemosphere.2016.02.005.xml'
# Converted 'Cross_Document_Linking/XML/10.1016_j.chemosphere.2016.02.005.xml' to Markdown at 'Cross_Document_Linking/MD/10.1016_j.chemosphere.2016.02.005.md'
# Action: reading the document
# finding all properties of name 1: HKUST-1
#
# Result:
# - Metal Precursor: Not Provided
# - Organic Linker: Not Provided
# - Solvent: Not Provided
# - Temperature: Not Provided
# - Reaction Type: Not Provided
# - Reaction Time: Not Provided
# - Synthesis Procedure: Not Provided
# - Additional Conditions: Not Provided
# - Justification: The provided documents do not contain specific synthesis details for HKUST-1.
#
# Parsed Result:
# Metal Precursor: Not Provided
# Organic Linker: Not Provided
# Solvent: Not Provided
# Temperature: Not Provided
# Reaction Type: Not Provided
# Reaction Time: Not Provided
# Summarized Procedure: Not Provided
# Additional Conditions: Not Provided
# Exact Sentences: The provided documents do not contain specific synthesis details for HKUST-1.
#
#
# ✅ 193 MOFs processed so far. 0 remaining this batch. Progress saved to Cross_Document_Linking/XML/synthesis_results/synthesis_extractions.csv.
# ✅ Processing complete! All MOFs processed.

# %%
batch_results_df
# Out:
#                                       Metal Precursor  \
# 0                                       Cu(NO3)2.3H2O
# 1                           Copper nitrate trihydrate
# 2                                    Copper wire (Cu)
# 3                     Copper nitrate hemipentahydrate
# 4                           Copper nitrate trihydrate
# ..                                                ...
# 188         Copper nitrate trihydrate (Cu(NO3)2·3H2O)
# 189                      Cu(NO3)2·3H2O, Cu(NO3)2·6H2O
# 190  Cu(CH3COO)2·H2O (Copper(II) acetate monohydrate)
# 191                                   Cu(CH3COO)2·H2O
# 192                                      Not Provided
#
#                                                 Linker  \
# 0              H3BTC (1,3,5-benzenetricarboxylic acid)
# 1               Benzene-1,3,5-tricarboxylic acid (BTC)
# 2                BTC (1,3,5-benzenetricarboxylic acid)
# 3      Trimesic acid (1,3,5-benzenetricarboxylic acid)
# 4                                  TMA (trimesic acid)
# ..                                                 ...
# 188            H3BTC (1,3,5-benzenetricarboxylic acid)
# 189            H3BTC (1,3,5-benzenetricarboxylic acid)
# 190  H3BTC (trimesic acid, [1,3,5-benzenetricarboxy...
# 191             1,3,5-benzene tricarboxylic acid (BTC)
# 192                                       Not Provided
#
#                                                Solvent           Temperature  \
# 0    Ethanol, DMF (dimethylformamide) in a ratio of...                100 °C
# 1                                         Not Provided                 50 °C
# 2               Dimethylformamide (DMF)/H2O (1:1, v/v)          Not Provided
# 3                           Ethanol, DMF/Water/Ethanol            60°C, 79°C
# 4                             Deionized water, Ethanol                 85 °C
# ..                                                 ...                   ...
# 188                 Deionized water, anhydrous ethanol                150 °C
# 189                                     Water, Ethanol  80 °C, 120 °C, 393 K
# 190  25% aqueous solution of dimethylformamide (DMF...          Not Provided
# 191                                       Not Provided          Not Provided
# 192                                       Not Provided          Not Provided
#
#                                          Reaction Time  \
# 0                                             10 hours
# 1                                              3 hours
# 2                                         Not Provided
# 3    5 hours (batch), 13 seconds to 5 minutes (cont...
# 4                                              3 hours
# ..                                                 ...
# 188                                           15 hours
# 189                                  3 h, 12 h, 30 min
# 190            3 hours stirring, 30 minutes sonication
# 191                                       Not Provided
# 192                                       Not Provided
#
#                                       Reaction Type  \
# 0                                      Solvothermal
# 1                                      Solvothermal
# 2                               Sonoelectrochemical
# 3                  Solvothermal, Microwave assisted
# 4                               Hydro/solvo-thermal
# ..                                              ...
# 188                                    Solvothermal
# 189  Solvothermal, Hydrothermal, Microwave-assisted
# 190                                    Not Provided
# 191                                    Not Provided
# 192                                    Not Provided
#
#                                    Synthesis Procedure  \
# 0    Dissolve 1 g of H3BTC in 30 mL of a mixture of...
# 1    Copper nitrate trihydrate and benzene-1,3,5-tr...
# 2    Dissolve NaNO3 and 1,3,5-benzenetricarboxylic ...
# 3    For batch synthesis: Mix copper nitrate hemipe...
# 4    Dissolve 0.03 mol of copper nitrate trihydrate...
# ..                                                 ...
# 188  Disperse and dissolve 5 g of Cu(NO3)2·3H2O in ...
# 189  Solvothermal Approach: Continuously stir H3BTC...
# 190  Prepare a solution of 1.2 g Cu(CH3COO)2·H2O an...
# 191                                       Not Provided
# 192                                       Not Provided
#
#                                  Additional Conditions  \
# 0                                         Not Provided
# 1                                 Atmospheric pressure
# 2    Electrical potential difference: 12V; Ultrasou...
# 3    For microwave synthesis, maintain microwave po...
# 4    The molar ratio of TEA, Cu2+, and TMA is 6:3:2...
# ..                                                 ...
# 188                                       Not Provided
# 189                                       Not Provided
# 190                                       Not Provided
# 191                                       Not Provided
# 192                                       Not Provided
#
#                                          Justification  \
# 0    HKUST-1 synthesis was performed based on the r...
# 1    In a typical synthesis process, copper nitrate...
# 2    In a typical process, NaNO3 (0.24molL−1) and 1...
# 3    "All batch tests were performed using 6mL of t...
# 4    Firstly, 0.03 mol of copper nitrate trihydrate...
# ..                                                 ...
# 188  First, 5 g of Cu(NO3)2·3H2O was dispersed and ...
# 189  The most extensively utilized technique for th...
# 190  HKUST-1 nanoparticles were prepared with sligh...
# 191  Zn(NO3)2·6H2O, Co(NO3)2·6H2O, Cu(CH3COO)2·H2O,...
# 192  The provided documents do not contain specific...
#
#                              Reference MOF Name
# 0         10.1016/j.nanoso.2021.100773  HKUST-1
# 1           10.1016/j.pnsc.2018.08.002  HKUST-1
# 2       10.1016/j.synthmet.2016.07.003  HKUST-1
# 3            10.1016/j.cej.2017.05.169  HKUST-1
# 4      10.1016/j.micromeso.2018.05.027  HKUST-1
# ..                                 ...      ...
# 188         10.1016/j.jpcs.2022.111094  HKUST-1
# 189         10.1016/j.hazl.2023.100094  HKUST-1
# 190         10.1016/j.apsb.2024.03.014  HKUST-1
# 191       10.1016/j.memsci.2020.118412  HKUST-1
# 192  10.1016/j.chemosphere.2016.02.005  HKUST-1
#
# [193 rows x 11 columns]
