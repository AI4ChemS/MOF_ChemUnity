# %% [markdown]
# # Task 2a – Inferencing: Linker Length and Pore Size vs Water Stability
#
# In this notebook, we test whether a knowledge graph-augmented LLM can infer scientific relationships between structural features and material properties.
#
# The LLM is provided with real examples retrieved from the knowledge graph — specifically, MOFs with known linker lengths and pore sizes. Rather than memorizing trends, the LLM is prompted to reason from these examples and infer the relationship between linker length and pore size. This setup showcases the ability of KG-augmented models to support grounded scientific intuition.

# %% [markdown]
# ## Accessing the KG

# %%
from src.MOF_ChemUnity.Agents.QueryAgent import QueryGenerationAgent
import pandas as pd

# %%
# Connect to graph
agent = QueryGenerationAgent()
data = agent.run_full_query("List 30 MOFs with their names (every name delimited by <|>), computatational smiles linker, pore size, and water stability. Only include MOFs with a value for each field. Include references for all properties")
# Out:
# ✅ Connected to Neo4j.
# Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.AggregationSkippedNull} {category: UNRECOGNIZED} {title: The query contains an aggregation function that skips null values.} {description: null value eliminated in set function.} {position: None} for query: 'MATCH (m:MOF)\nOPTIONAL MATCH (m)-[:has_name]->(n:MOF_Name)\nWITH m, collect(n.name) AS mof_names\nOPTIONAL MATCH (m)-[r1:has_synthesis]->(s:Synthesis)\nWITH m, mof_names, r1.linker AS smiles_linker\nOPTIONAL MATCH (m)-[r2:has_property]->(p2:Property)\nWHERE p2.name = "Pore Diameter" AND r2.value IS NOT NULL\nWITH m, mof_names, smiles_linker, r2.value AS pore_size, r2.reference AS pore_size_reference\nOPTIONAL MATCH (m)-[r3:has_property]->(p3:Property)\nWHERE p3.name = "Water Stability" AND r3.value IS NOT NULL\nWITH m, mof_names, smiles_linker, pore_size, pore_size_reference, r3.value AS water_stability, r3.reference AS water_stability_reference\nWHERE smiles_linker IS NOT NULL AND pore_size IS NOT NULL AND water_stability IS NOT NULL\nRETURN m.refcode, apoc.text.join(mof_names, "<|>") AS mof_names, smiles_linker, pore_size, pore_size_reference, water_stability, water_stability_reference\nLIMIT 30'
#    m.refcode                                          mof_names  \
# 0     CELZIE                                    3<|>CAU-10-OCH3
# 1     ESIGES                                             NTHU-2
# 2     YATDUV                     NH4@ZnPzC<|>NH4Â·Zn3OHÂ­(PzC)3
# 3     QOVDEL      Ni-STA-12<|>St Andrews nanoporous material-12
# 4     QOVDAH                          Ni-STA-12 (hydrated form)
# 5     SISZEC  [Cd3(C8H3SO7)2(C10H8N4)3(C3H7NO)2](C3H7NO)2Â·(...
# 6     OJAWII          Fe-ICR-6<|>Fe-ICR-2<|>Fe-ICR-4<|>Fe-ICR-7
# 7   KETHEY01                       compound 1<|>[Cd(pyip)(dmf)]
# 8     CIKCOQ                       compound 2<|>[Cd(pyip)(doa)]
# 9     GEDTAM                                              UCY-2
# 10    KADLOT   2<|>[(Cu2I2)Â­Cu2(C11H7N2O2)4]Â·(DMF)7.4(H2O)4.6
# 11    NOFQIK                                   TCuI<|>TMBPÂ·CuI
# 12    QEFNAQ                   [Cu(pymo)2]Â·NH4ClO4<|>1Â·NH4ClO
# 13    JESTIN         1<|>{[Cd2(sdb)2(pcih)2]Â·2DMFÂ·H2O}<|>1H2O
# 14    KOHKIC  1<|>[Na0.5Zn4.75(m3-OH)2(BTB)2(HBTB)(H2O)0.5]5...
# 15    NADKEK                               Structure 2<|>STA-13
# 16    PELRIJ                               1<|>[Cu3(L1)2(H2O)3]
# 17    NABMUA                      Mg-MOF-1<|>[Mg(3,5-PDC)(H2O)]
# 18    XULFEQ    compound 1<|>[Zn4(btc)2(4-bph)(H2O)4]nÂ·2n(H2O)
# 19    VUGWUR    compound 1<|>[La(TTTPC)(O)2(NO2)2(Cl)]Â·(H2O)10
# 20    HICVOG          complex 1<|>1a<|>{[Zn2(bpt)(btc)]Â·4H2O}n
# 21    LUDLED                   compound 1<|>HKUST-1<|>Cu3(BTC)2
# 22    GUVBOQ           compound 1<|>[Zn9IJOH)2L6]IJH3O)2IJH2O)6
# 23    RIRDIH                                          Co-ZIF-81
# 24    RIRDED                                          Co-ZIF-69
# 25    AVILEY                                      Ir-PMOF-1(Hf)
# 26    ZUCKIT     POST-66(Y)<|>POST-66(Y)-wt<|>POST-66(Y)-wt-24h
# 27    MUMLIR         Compound 1<|>1a<|>[Zn3(HL)2(fma)2]$DMA$H2O
# 28    QODJEB                 3<|>compound 3<|>[Zn2(pypz)2(bdc)]
# 29    FEWTUY                 compound 3<|>[Ni5(OH2)3(4-pyc)10]n
#
#                                         smiles_linker  \
# 0                           5-methoxyisophthalic acid
# 1   C13N2H14 (4,4‘-trimethylene dipyridine, tmdp),...
# 2               H2PzC (1H-pyrazole-4-carboxylic acid)
# 3          N,N′-piperazinebismethylenephosphonic acid
# 4          N,N′-piperazinebismethylenephosphonic acid
# 5   ABPY (4,4′-azopyridine), NaSIPA (sodium salt o...
# 6                                           H2BBP(Me)
# 7          H2pyip (5-(pyridine-4-yl)isophthalic acid)
# 8          H2pyip (5-(pyridine-4-yl)isophthalic acid)
# 9   H3CIP (5-(4-carboxybenzylideneamino)isophthali...
# 10      H2-4,5-pmbc (4-(Pyrimidin-5-yl)­benzoic Acid)
# 11        TMBP (3,3′,5,5′-tetramethyl-4,4′-bipyrazol)
# 12                         pymo (2-hydroxypyrimidine)
# 13  pcih (4-pyridinecarboxaldehyde isonicotinoyl h...
# 14              H3BTB (benzene-1,3,5-tribenzoic acid)
# 15  H4L¢ (N,N'-2-methylpiperazinebis(methylenephos...
# 16  H3L1 [4,4',4''-[1,3,5-benzenetriyltris(carbony...
# 17           3,5-PDC (3,5-pyridine dicarboxylic acid)
# 18  H3btc (1,3,5-benzenetricarboxylic acid), 4-bpo...
# 19  H3TTTPC (1,1′,1″-tris(2,4,6-trimethylbenzene-1...
# 20  Hbpt (3,5-bis(pyrazinyl)-1,2,4-trizole), H3btc...
# 21                 BTC (benzene-1,3,5-tricarboxylate)
# 22  H3L (1,3,5-tri(3-hydroxyl-4-carboxyl)phenylben...
# 23  2-nitroimidazole (nIM), bromo-benzimidazole (B...
# 24        2-nitroimidazole (nIM), chlorobenzimidazole
# 25    Ir(TCPP)Cl (tetrakis(4-carboxyphenyl)porphyrin)
# 26  H3hmtt (methyl substituted truxene tricarboxyl...
# 27  HL (1-(5-tetrazolyl)-4-(1-imidazolyl)benzene),...
# 28  Hpypz (4-(1H-pyrazol-4-yl)pyridine), H2bdc (1,...
# 29                      4-pyc (4-pyridinecarboxylate)
#
#                                         pore_size  \
# 0                                             2.5
# 1                                      1.36, 21.8
# 2                                               1
# 3                                               1
# 4                                               1
# 5                                       5.0 × 8.0
# 6                                            2.16
# 7                                       8.2 x 8.2
# 8   8.0 × 11.3, 7.3 × 11.3, 7.3 × 10.2, 7.3 × 5.1
# 9                                             3-4
# 10                                              9
# 11                                            5.2
# 12                                            8.1
# 13                                            4.4
# 14                                            6.0
# 15                                              3
# 16                                           21.4
# 17                                            4.0
# 18                                            3.8
# 19                                            7.5
# 20                                            4.1
# 21                                           5.85
# 22                                       Around 1
# 23                                            6.2
# 24                                            7.9
# 25                                            1.6
# 26                                   3.8 and 13.9
# 27                                      8.8 - 8.8
# 28                                            1.6
# 29                                           0.90
#
#               pore_size_reference water_stability  \
# 0               10.1021/cm3025445          Stable
# 1               10.1021/ja0390146        Unstable
# 2         10.1021/acs.cgd.7b00346        Unstable
# 3               10.1021/ja804936z          Stable
# 4               10.1021/ja804936z          Stable
# 5         10.1021/acs.cgd.8b01327          Stable
# 6   10.1021/acs.inorgchem.0c00201        Unstable
# 7               10.1021/cg400486q          Stable
# 8               10.1021/cg400486q          Stable
# 9               10.1021/ic3005085          Stable
# 10        10.1021/acs.cgd.5b01307          Stable
# 11              10.1021/ic500677t          Stable
# 12              10.1021/ja002624a        Unstable
# 13  10.1021/acs.inorgchem.8b00078          Stable
# 14               10.1039/b809069f        Unstable
# 15             10.1039/c0dt00233j          Stable
# 16             10.1039/c2ce26015h        Unstable
# 17             10.1039/c0jm01125h          Stable
# 18               10.1039/b906105n          Stable
# 19             10.1039/C5DT01598G          Stable
# 20             10.1039/C3CE40574E          Stable
# 21             10.1039/c3nr04161a          Stable
# 22             10.1039/C5CE01320H          Stable
# 23             10.1039/C3CE42075B          Stable
# 24             10.1039/C3CE42075B          Stable
# 25             10.1039/C6SC03288E          Stable
# 26         10.1002/anie.201506391        Unstable
# 27             10.1039/C5RA05945C        Unstable
# 28             10.1039/C9CE00227H        Unstable
# 29         10.1002/ejic.201201461        Unstable
#
#         water_stability_reference
# 0               10.1021/cm3025445
# 1               10.1021/ja0390146
# 2         10.1021/acs.cgd.7b00346
# 3               10.1021/ja804936z
# 4               10.1021/ja804936z
# 5         10.1021/acs.cgd.8b01327
# 6   10.1021/acs.inorgchem.0c00201
# 7               10.1021/cg400486q
# 8               10.1021/cg400486q
# 9               10.1021/ic3005085
# 10        10.1021/acs.cgd.5b01307
# 11              10.1021/ic500677t
# 12              10.1021/ja002624a
# 13  10.1021/acs.inorgchem.8b00078
# 14               10.1039/b809069f
# 15             10.1039/c0dt00233j
# 16             10.1039/c2ce26015h
# 17             10.1039/c0jm01125h
# 18               10.1039/b906105n
# 19             10.1039/C5DT01598G
# 20             10.1039/C3CE40574E
# 21             10.1039/c3nr04161a
# 22             10.1039/C5CE01320H
# 23             10.1039/C3CE42075B
# 24             10.1039/C3CE42075B
# 25             10.1039/C6SC03288E
# 26         10.1002/anie.201506391
# 27             10.1039/C5RA05945C
# 28             10.1039/C9CE00227H
# 29         10.1002/ejic.201201461

# %%
# References for all properties are the same, so we can merge them into one column
# Drop the 'pore_size_reference' column
data = data.drop(columns=['pore_size_reference'])

# Rename 'water_stability_reference' column to 'reference'
data = data.rename(columns={'water_stability_reference': 'reference'})

# %% [markdown]
# ## Responses

# %% [markdown]
# First, here is the question both LLM's will be seeing

# %%
question = "How does pore volume and linker length affect the water stability of MOFs? Justify your answer with chemistry reasoning. Please keep your response concise but informative"

# %% [markdown]
# ### Graph-RAG Enabled GPT-4o

# %%
# Auto-format RAG prompt from a DataFrame
def generate_few_shot_prompt(data, question, max_examples=15):
    # Limit to first N examples
    subset = data.head(max_examples)

    # Start with task-agnostic intro
    lines = ["Here are some MOFs with their associated properties:"]
    for _, row in subset.iterrows():
        props = []
        for col in data.columns:
            if "refcode" in col.lower() or "mof_name" in col.lower():
                continue  # skip any column containing 'refcode' or 'name'
            value = row[col]
            value_str = str(value).strip()
            if value_str.startswith('[') and value_str.endswith(']'):
                value_str = value_str[1:-1]  # remove brackets
            props.append(f"{col} = {value_str}")
        lines.append("- " + ", ".join(props))

    context = "\n".join(lines)
    rag_prompt = f"{context}\n\nUse your expert MOF knowledge to make use of this data in your response. Any time you explicitly use this data in your response, include the reference in brackets beside it. Note, the data you have access to is only visible to you \n{question.strip()}"
    return rag_prompt


# Now use the function to generate the prompt
rag_prompt = generate_few_shot_prompt(data, question)
print(rag_prompt)
# Out:
# Here are some MOFs with their associated properties:
# - smiles_linker = 5-methoxyisophthalic acid, pore_size = 2.5, water_stability = Stable, reference = 10.1021/cm3025445
# - smiles_linker = C13N2H14 (4,4‘-trimethylene dipyridine, tmdp), p-C6H4(COOH)2 (terephthalic acid, BDC), pore_size = 1.36, 21.8, water_stability = Unstable, reference = 10.1021/ja0390146
# - smiles_linker = H2PzC (1H-pyrazole-4-carboxylic acid), pore_size = 1, water_stability = Unstable, reference = 10.1021/acs.cgd.7b00346
# - smiles_linker = N,N′-piperazinebismethylenephosphonic acid, pore_size = 1, water_stability = Stable, reference = 10.1021/ja804936z
# - smiles_linker = N,N′-piperazinebismethylenephosphonic acid, pore_size = 1, water_stability = Stable, reference = 10.1021/ja804936z
# - smiles_linker = ABPY (4,4′-azopyridine), NaSIPA (sodium salt of 5-sulfoisopthalic acid), pore_size = 5.0 × 8.0, water_stability = Stable, reference = 10.1021/acs.cgd.8b01327
# - smiles_linker = H2BBP(Me), pore_size = 2.16, water_stability = Unstable, reference = 10.1021/acs.inorgchem.0c00201
# - smiles_linker = H2pyip (5-(pyridine-4-yl)isophthalic acid), pore_size = 8.2 x 8.2, water_stability = Stable, reference = 10.1021/cg400486q
# - smiles_linker = H2pyip (5-(pyridine-4-yl)isophthalic acid), pore_size = 8.0 × 11.3, 7.3 × 11.3, 7.3 × 10.2, 7.3 × 5.1, water_stability = Stable, reference = 10.1021/cg400486q
# - smiles_linker = H3CIP (5-(4-carboxybenzylideneamino)isophthalic acid), pore_size = 3-4, water_stability = Stable, reference = 10.1021/ic3005085
# - smiles_linker = H2-4,5-pmbc (4-(Pyrimidin-5-yl)­benzoic Acid), pore_size = 9, water_stability = Stable, reference = 10.1021/acs.cgd.5b01307
# - smiles_linker = TMBP (3,3′,5,5′-tetramethyl-4,4′-bipyrazol), pore_size = 5.2, water_stability = Stable, reference = 10.1021/ic500677t
# - smiles_linker = pymo (2-hydroxypyrimidine), pore_size = 8.1, water_stability = Unstable, reference = 10.1021/ja002624a
# - smiles_linker = pcih (4-pyridinecarboxaldehyde isonicotinoyl hydrazone), H2sdb (4,4′-sulfonyldibenzoic acid), pore_size = 4.4, water_stability = Stable, reference = 10.1021/acs.inorgchem.8b00078
# - smiles_linker = H3BTB (benzene-1,3,5-tribenzoic acid), pore_size = 6.0, water_stability = Unstable, reference = 10.1039/b809069f
#
# Use your expert MOF knowledge to make use of this data in your response. Any time you explicitly use this data in your response, include the reference in brackets beside it. Note, the data you have access to is only visible to you
# How does pore volume and linker length affect the water stability of MOFs? Justify your answer with chemistry reasoning. Please keep your response concise but informative

# %%
from openai import OpenAI
# Initialize client (uses OPENAI_API_KEY from .env automatically)
client = OpenAI()

# Send the prompt to GPT-4
response = client.chat.completions.create(
    model="gpt-4o",
    messages=[
        {"role": "system", "content": "You are a materials science expert."},
        {"role": "user", "content": rag_prompt}
    ],
    temperature=0.5
)

# Extract and print the response
rag_answer = response.choices[0].message.content.strip()
print(rag_answer)
# Out:
# The water stability of Metal-Organic Frameworks (MOFs) is influenced by several factors, including pore volume and linker length. Here's how these factors interplay:
#
# 1. **Pore Volume**:
#    - Larger pore volumes can sometimes lead to reduced water stability. This is because larger pores may allow more water molecules to penetrate the framework, potentially interacting with and disrupting metal-ligand bonds. For example, the MOF with a large pore size of 8.1 Å (pymo) is unstable in water [10.1021/ja002624a]. Conversely, smaller pores might restrict water access, enhancing stability, as seen in MOFs with smaller pore sizes like 1 Å (N,N′-piperazinebismethylenephosphonic acid), which are stable [10.1021/ja804936z].
#
# 2. **Linker Length**:
#    - Longer linkers usually increase the flexibility of the framework, which can make it more susceptible to structural distortion upon water adsorption. This is evident in some MOFs with longer linkers, which are unstable, such as H2BBP(Me) with a pore size of 2.16 Å [10.1021/acs.inorgchem.0c00201]. In contrast, shorter and more rigid linkers can enhance stability by maintaining the framework's integrity, as seen with stable MOFs using shorter linkers like H2pyip with pore sizes of 8.2 x 8.2 Å [10.1021/cg400486q].
#
# 3. **Chemical Composition and Functional Groups**:
#    - The presence of hydrophobic functional groups or robust bonding (e.g., phosphonate groups) can enhance water stability, regardless of pore size or linker length. For instance, the stable MOF with N,N′-piperazinebismethylenephosphonic acid [10.1021/ja804936z] benefits from strong phosphonate-metal bonds.
#
# Overall, while larger pore volumes and longer linkers can compromise water stability, the chemical nature and bonding within the MOF play crucial roles. Stability is often a balance of these factors, with chemical robustness and structural rigidity being key to resisting water-induced degradation.

# %% [markdown]
# ### Vanilla GPT-4o

# %%
# Send the prompt to GPT-4
response = client.chat.completions.create(
    model="gpt-4o",
    messages=[
        {"role": "system", "content": "You are a materials science expert."},
        {"role": "user", "content": question}
    ],
    temperature=0.5  # slightly higher to allow some reasoning flexibility
)

# Extract and print the response
vanilla_answer = response.choices[0].message.content.strip()
print(vanilla_answer)
# Out:
# The water stability of Metal-Organic Frameworks (MOFs) is influenced by both pore volume and linker length due to their impact on the structure and chemical environment of the MOF.
#
# 1. **Pore Volume:**
#    - **Larger Pores:** MOFs with larger pore volumes typically have greater surface areas exposed to water, which can increase the likelihood of hydrolytic degradation. Water molecules can more easily penetrate and interact with the metal nodes, potentially leading to hydrolysis of metal-linker bonds.
#    - **Smaller Pores:** Conversely, smaller pore volumes might limit water access, potentially enhancing stability by reducing the surface area exposed to water.
#
# 2. **Linker Length:**
#    - **Longer Linkers:** These can increase the distance between metal nodes, potentially weakening the overall framework due to reduced structural rigidity. Longer linkers might also introduce more flexibility, allowing water molecules easier access to vulnerable sites.
#    - **Shorter Linkers:** These generally provide more rigidity and closer packing of the framework, which can enhance stability by reducing the accessibility of water to reactive sites.
#
# **Chemical Reasoning:**
# - **Hydrolysis Susceptibility:** The coordination environment of the metal centers plays a crucial role. MOFs with coordinatively unsaturated metal sites are more prone to hydrolysis. Larger pore volumes and longer linkers can exacerbate this by increasing exposure.
# - **Linker Chemistry:** The chemical nature of the linker (e.g., hydrophobic vs. hydrophilic) also affects water stability. Hydrophobic linkers can repel water, enhancing stability, while hydrophilic linkers can attract water, increasing susceptibility to degradation.
#
# Overall, optimizing pore volume and linker length, along with considering the chemical nature of the components, is crucial for designing water-stable MOFs.

# %% [markdown]
# # Task 2b – Inferencing: Metal Node and Decomposition Temperature
#
# In this notebook, we test whether a knowledge graph-augmented LLM can infer scientific relationships between structural features and material properties.
#
# The LLM is provided with real examples retrieved from the knowledge graph — specifically, MOFs with experimentally measured decomposition temperatures and their Metal Nodes. We will use this data as few-shot context into the LLM, and compare to its vanilla (no injected contexted) response.

# %%
# Connect to graph
agent = QueryGenerationAgent()
data = agent.run_full_query("List 50 MOFs with their names (every name delimited by <|>), thermal stability, and metal. Only include MOFs with a value for thermal stability and metal. Include references for all properties")
# Out:
# ✅ Connected to Neo4j.
#    m.refcode                                          mof_names  \
# 0     WOCKOP                [Cd(Î¼-tp)(Î¼-bpp)(H2O)]Â·nnH2O<|>3
# 1     CURYAQ                  [CuBr2(L1)]Â·nn(MeOH)<|>complex 3
# 2     UNABAN                               Zn(LTP)2<|>complex 1
# 3     UMUZUY                               complex 3<|>Ni(LTP)2
# 4     BOLHAM              compound 1<|>âˆž3[SmCl3(1,4-Ph(CN)2)]
# 5     RESWUI        compound 1<|>Er2(BDC)3(DMF)2(H2O)2Â·H2O<|>1
# 6     RESWOC       2<|>compound 2<|>Er2(BDC-F4)3(DMF)(H2O)Â·DMF
# 7     ECUGIU                           BaAMP<|>Ba[HN(CH2PO3H)3]
# 8     RAVFIF  compound 10<|>[NH2(CH3)2][Yb(MDIP)(H2O)]Â·0.5N...
# 9     LISBIZ   Zn5(Î¼3-OH)2(BTA)2(tp)3<|>Complex 1<|>Compound 1
# 10    LISBUL          Zn(BTA)(chdc)0.5<|>Complex 2<|>Compound 2
# 11    LISBEV            Zn(BTA)(ap)0.5<|>Complex 3<|>Compound 3
# 12    CEZZIR                      compound 2<|>[Pb(INO)2]Â·nH2O
# 13    CEZZEN                     compound 1<|>[Pb(INO)2]2Â·7H2O
# 14    OLONAG      compound 2<|>{[Sr3(H2O)10][Ag6(mna)6]Â·12H2O}
# 15    PAQTIM                MIL-141(Cs)<|>Fe(Ni-TCPP)Csâ€¢(DMF)
# 16    PAQTOS                MIL-141(Rb)<|>Fe(Ni-TCPP)Rbâ€¢(DMF)
# 17    PAQVEK                  MIL-141(K)<|>Fe(Ni-TCPP)Kâ€¢(DMF)
# 18    COMGIV              compound 1<|>{Na2[Cd(odpa)(H2O)]}(n1)
# 19    COMGUH   compound 3<|>{Na2[Cd3(odpa)2(H2O)5]Â·1.5H2O}(n3)
# 20  DILDEI01                            compound 1<|>Zn(pymtz)2
# 21    KINFAQ      Tm4(BDC)6(H2O)2(DMF)2Â·2DMFÂ·2H2O<|>complex 7
# 22  IJASES01  Tm(BDC)1.5(H2O)Â·0.5DMFÂ·C2H5OHÂ·2H2O<|>complex 6
# 23    FIDFEG                             CuÂ·NDSÂ·B3PVA<|>FNP1d
# 24    WIJDAV                          1<|>Zn6(IDC)4(OH)2(Hprz)2
# 25    ASEBAD                           compound 1<|>C32H18O7N4U
# 26    ALAHUS    compound 1<|>[Tb3(L)2(HCOO)Â­(H2O)5]Â·DMFÂ·4H2O
# 27    QUSSOO  compound 3<|>[Zn10(hpc1)4(BDC)7(HCO2)2(OH)4(Et...
# 28    CELZIE                                    3<|>CAU-10-OCH3
# 29    HIQPII                           [Zn(Me4BPZ)]<|>Species 1
# 30    HIQPEE                           [Co(Me4BPZ)]<|>Species 2
# 31    QURZAF            complex 4<|>[SmCu(Hbic)3(C2O4)0.5]Â·H2O
# 32    YOMVIG                      CoAPO-LAU<|>MAPO-LAU (M = Co)
# 33    GOMRAC                      ZnAPO-LAU<|>MAPO-LAU (M = Zn)
# 34    NIGBOW                             COMOC-2(VIV)<|>COMOC-2
# 35    AVEROJ                          [Cd(trz)Cl]Â·H2O<|>1Â·H2O
# 36  FODGUB02                      2<|>Î±-Cd2(Î¼3-OH)2(2,4-pyda)
# 37  FODGUB01                      3<|>Î²-Cd2(Î¼3-OH)2(2,4-pyda)
# 38    HEDCEA                          2<|>[Zn2(obb)2(bpy)]Â·DMF
# 39    CIKHAH                       Complex 1<|>La(HL)(H2L)(H2O)
# 40    CIKGOU                       Complex 3<|>Pr(HL)(H2L)(H2O)
# 41    CIKGEK                       Complex 5<|>Sm(HL)(H2L)(H2O)
# 42    KAXTEK                        compound 2<|>Zn(mpdc)(bpea)
# 43    OTAXOX                    Î³-Mg-formate<|>Î³-[Mg3(O2CH)6]
# 44    WUWVIU                     compound 2<|>[Cu((S)-imp)2]âˆž
# 45    EBOJOV  MIL-79<|>Eu(III)5(OH)9(H2O)6(O2Câˆ’C2H2âˆ’CO2)...
# 46    AMOROK                 compound 1<|>Sm(O3P-C2H4-SO3)(H2O)
# 47    UGELIB  ULM-16<|>Ga4(PO4)4F1.33(OH)0.67Â·1.5NC5H12Â·0....
# 48    OYIVEY                   Cu9(4-TBA)10(C2H5OH)2<|>Cu-TBA-1
# 49    OYIVIC                Cu2(4-TBA)2(DMF)(C2H5OH)<|>Cu-TBA-2
#
#                              thermal_stability    thermal_stability_reference  \
# 0                             Stable up to 358              10.1021/cg701232n
# 1                                          130              10.1021/cg901327m
# 2                                          210              10.1021/cg1009175
# 3                                          220              10.1021/cg1009175
# 4                 Decomposition at 321 and 375              10.1021/ic800635u
# 5                                          480              10.1021/ic060568u
# 6     loses H2O, free DMF, and coordinated DMF              10.1021/ic060568u
# 7                    No weight loss up to ≈673              10.1021/ic301192y
# 8                                          6.3              10.1021/cg201283a
# 9                                      467−528              10.1021/cg070356n
# 10                               519 to 548 °C              10.1021/cg070356n
# 11                                     436-487              10.1021/cg070356n
# 12                                         310              10.1021/cg060535p
# 13                                         325              10.1021/cg060535p
# 14                                         310        10.1021/acs.cgd.6b00463
# 15                                         300              10.1021/cm2025747
# 16                                         300              10.1021/cm2025747
# 17                                         300              10.1021/cm2025747
# 18                            Stable up to 275              10.1021/cg8003257
# 19                            stable below 250              10.1021/cg8003257
# 20                                         310              10.1021/cg9013398
# 21                                         560              10.1021/cg400531j
# 22                                         560              10.1021/cg400531j
# 23                            Stable up to 430        10.1021/acs.cgd.7b01574
# 24                            Stable up to 340              10.1021/ic7004908
# 25                            Stable up to 465        10.1021/acs.cgd.6b00429
# 26                           Stable up to ∼420  10.1021/acs.inorgchem.5b02294
# 27                                   Up to 300  10.1021/acs.inorgchem.5b00975
# 28                                         450              10.1021/cm3025445
# 29                                   above 350              10.1021/cg400495w
# 30                                   above 350              10.1021/cg400495w
# 31                     Decomposition above 310              10.1021/cg900571v
# 32          Stable at 550, collapses above 600              10.1021/ic801405e
# 33          Stable at 550, collapses above 600              10.1021/ic801405e
# 34                            Stable up to 350              10.1021/ic301338a
# 35                                   Up to 350              10.1021/ic100610t
# 36                            Up to 340 to 350              10.1021/cg049610r
# 37                                     340−350              10.1021/cg049610r
# 38                                        8.18              10.1021/ic300778m
# 39                            3.1% weight loss              10.1021/cg400877g
# 40                                         800              10.1021/cg400877g
# 41                 Very high thermal stability              10.1021/cg400877g
# 42         No significant loss up to about 320              10.1021/cg201432w
# 43                                     155−370              10.1021/ic102057p
# 44                                         230              10.1021/cg1001368
# 45                                         573              10.1021/cm035045o
# 46                        Decomposes above 400              10.1021/ic101786r
# 47  Three-step weight loss between 25 and 1050              10.1021/cm011247d
# 48                                         230              10.1021/cm2004352
# 49                                         230              10.1021/cm2004352
#
#      metal_names
# 0             Cd
# 1             Cu
# 2             Zn
# 3             Ni
# 4             Sm
# 5             Er
# 6             Er
# 7             Ba
# 8             Yb
# 9             Zn
# 10            Zn
# 11            Zn
# 12            Pb
# 13            Pb
# 14       Ag<|>Sr
# 15  Fe<|>Ni<|>Cs
# 16  Fe<|>Ni<|>Rb
# 17   Fe<|>Ni<|>K
# 18       Cd<|>Na
# 19       Cd<|>Na
# 20            Zn
# 21            Tm
# 22            Tm
# 23            Cu
# 24            Zn
# 25             U
# 26            Tb
# 27            Zn
# 28            Al
# 29            Zn
# 30            Co
# 31       Cu<|>Sm
# 32       Co<|>Al
# 33       Zn<|>Al
# 34             V
# 35            Cd
# 36            Cd
# 37            Cd
# 38            Zn
# 39            La
# 40            Pr
# 41            Sm
# 42            Zn
# 43            Mg
# 44            Cu
# 45            Eu
# 46            Sm
# 47            Ga
# 48            Cu
# 49            Cu

# %%
# Rename 'water_stability_reference' column to 'reference'
data = data.rename(columns={'thermal_stability_reference': 'reference'})

# %% [markdown]
# ## Responses

# %%
question = "How does the selection of metal node affect the thermal stability of MOFs? Justify your answer with chemistry reasoning. Please keep your response concise!"

# %%
rag_prompt = generate_few_shot_prompt(data, question, max_examples=30)
print(rag_prompt)
# Out:
# Here are some MOFs with their associated properties:
# - thermal_stability = Stable up to 358, reference = 10.1021/cg701232n, metal_names = Cd
# - thermal_stability = 130, reference = 10.1021/cg901327m, metal_names = Cu
# - thermal_stability = 210, reference = 10.1021/cg1009175, metal_names = Zn
# - thermal_stability = 220, reference = 10.1021/cg1009175, metal_names = Ni
# - thermal_stability = Decomposition at 321 and 375, reference = 10.1021/ic800635u, metal_names = Sm
# - thermal_stability = 480, reference = 10.1021/ic060568u, metal_names = Er
# - thermal_stability = loses H2O, free DMF, and coordinated DMF, reference = 10.1021/ic060568u, metal_names = Er
# - thermal_stability = No weight loss up to ≈673, reference = 10.1021/ic301192y, metal_names = Ba
# - thermal_stability = 6.3, reference = 10.1021/cg201283a, metal_names = Yb
# - thermal_stability = 467−528, reference = 10.1021/cg070356n, metal_names = Zn
# - thermal_stability = 519 to 548 °C, reference = 10.1021/cg070356n, metal_names = Zn
# - thermal_stability = 436-487, reference = 10.1021/cg070356n, metal_names = Zn
# - thermal_stability = 310, reference = 10.1021/cg060535p, metal_names = Pb
# - thermal_stability = 325, reference = 10.1021/cg060535p, metal_names = Pb
# - thermal_stability = 310, reference = 10.1021/acs.cgd.6b00463, metal_names = Ag<|>Sr
# - thermal_stability = 300, reference = 10.1021/cm2025747, metal_names = Fe<|>Ni<|>Cs
# - thermal_stability = 300, reference = 10.1021/cm2025747, metal_names = Fe<|>Ni<|>Rb
# - thermal_stability = 300, reference = 10.1021/cm2025747, metal_names = Fe<|>Ni<|>K
# - thermal_stability = Stable up to 275, reference = 10.1021/cg8003257, metal_names = Cd<|>Na
# - thermal_stability = stable below 250, reference = 10.1021/cg8003257, metal_names = Cd<|>Na
# - thermal_stability = 310, reference = 10.1021/cg9013398, metal_names = Zn
# - thermal_stability = 560, reference = 10.1021/cg400531j, metal_names = Tm
# - thermal_stability = 560, reference = 10.1021/cg400531j, metal_names = Tm
# - thermal_stability = Stable up to 430, reference = 10.1021/acs.cgd.7b01574, metal_names = Cu
# - thermal_stability = Stable up to 340, reference = 10.1021/ic7004908, metal_names = Zn
# - thermal_stability = Stable up to 465, reference = 10.1021/acs.cgd.6b00429, metal_names = U
# - thermal_stability = Stable up to ∼420, reference = 10.1021/acs.inorgchem.5b02294, metal_names = Tb
# - thermal_stability = Up to 300, reference = 10.1021/acs.inorgchem.5b00975, metal_names = Zn
# - thermal_stability = 450, reference = 10.1021/cm3025445, metal_names = Al
# - thermal_stability = above 350, reference = 10.1021/cg400495w, metal_names = Zn
#
# Use your expert MOF knowledge to make use of this data in your response. Any time you explicitly use this data in your response, include the reference in brackets beside it:
# How does the selection of metal node affect the thermal stability of MOFs? Justify your answer with chemistry reasoning. Please keep your response concise!

# %%
from openai import OpenAI
# Initialize client (uses OPENAI_API_KEY from .env automatically)
client = OpenAI()

# Send the prompt to GPT-4
response = client.chat.completions.create(
    model="gpt-4o",
    messages=[
        {"role": "system", "content": "You are a materials science expert."},
        {"role": "user", "content": rag_prompt}
    ],
    temperature=0.5
)

# Extract and print the response
rag_answer = response.choices[0].message.content.strip()
print(rag_answer)
# Out:
# The thermal stability of Metal-Organic Frameworks (MOFs) is significantly influenced by the choice of metal nodes due to several chemical factors:
#
# 1. **Metal-Oxygen Bond Strength**: The thermal stability of a MOF is often correlated with the strength of the metal-oxygen bonds within the structure. For instance, metals with higher oxidation states typically form stronger metal-oxygen bonds, contributing to greater thermal stability. For example, Erbium-based MOFs exhibit high thermal stability up to 480°C [10.1021/ic060568u], likely due to strong Er-O bonds.
#
# 2. **Ionic Radius and Coordination Environment**: The size and coordination geometry of the metal ions can affect thermal stability. Smaller ions with high coordination numbers can create more robust frameworks. For example, Tm-based MOFs show high thermal stability up to 560°C [10.1021/cg400531j], possibly due to the compact nature of the Tm ions and their coordination environment.
#
# 3. **Metal Cluster Stability**: Some metals form more stable clusters within the MOF structure, enhancing overall stability. For example, Al-based MOFs are known for their high thermal stability (450°C) [10.1021/cm3025445], which can be attributed to the stability of aluminum clusters.
#
# 4. **Metal-Ligand Interaction**: The nature of the metal-ligand interaction, including the type of ligands used and their ability to stabilize the metal center, plays a crucial role. Cu-based MOFs, for instance, can be stable up to 430°C [10.1021/acs.cgd.7b01574], depending on the ligand environment.
#
# 5. **Metal Node Diversity**: Incorporating multiple metals can enhance stability by combining the benefits of different metal properties. For example, Fe<|>Ni<|>Cs-based MOFs have a thermal stability of 300°C [10.1021/cm2025747], indicating the potential for tailored stability through metal node diversity.
#
# In summary, the choice of metal node affects the thermal stability of MOFs through bond strength, ionic characteristics, cluster stability, and metal-ligand interactions, all of which are crucial in designing thermally robust MOFs.

# %%
# Send the prompt to GPT-4
response = client.chat.completions.create(
    model="gpt-4o",
    messages=[
        {"role": "system", "content": "You are a materials science expert."},
        {"role": "user", "content": question}
    ],
    temperature=0.5  # slightly higher to allow some reasoning flexibility
)

# Extract and print the response
vanilla_answer = response.choices[0].message.content.strip()
print(vanilla_answer)
# Out:
# The selection of the metal node in metal-organic frameworks (MOFs) significantly impacts their thermal stability due to several key factors:
#
# 1. **Metal-Oxygen Bond Strength**: The thermal stability of MOFs is largely dictated by the strength of the metal-oxygen bonds within the framework. Transition metals with higher oxidation states, such as Zr(IV) or Al(III), tend to form stronger and more thermally stable bonds with the organic linkers compared to metals with lower oxidation states.
#
# 2. **Coordination Geometry and Connectivity**: Metals that favor higher coordination numbers and robust geometries (e.g., octahedral or tetrahedral) contribute to a more stable framework. For instance, Zr-based MOFs often exhibit high connectivity and stable frameworks due to the strong Zr-O bonds and the ability to form dense, highly coordinated structures.
#
# 3. **Metal Ionic Radius**: A smaller ionic radius can lead to denser packing and stronger interactions within the framework, enhancing thermal stability. Metals like Al and Cr, with smaller ionic radii, often form more compact and stable structures.
#
# 4. **Electronic Configuration and Oxidation Potential**: Metals with a stable electronic configuration, such as those with filled d-orbitals, often provide additional stability. The ability of metals to undergo redox reactions without compromising the framework integrity also plays a role.
#
# In summary, selecting metal nodes with strong metal-oxygen bond strengths, high coordination numbers, smaller ionic radii, and stable electronic configurations generally enhances the thermal stability of MOFs.
